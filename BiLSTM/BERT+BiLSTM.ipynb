# %%
import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader, WeightedRandomSampler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from transformers import BertModel, get_linear_schedule_with_warmup
from torch.optim import AdamW
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score

# Cuda kontrolü
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Kullanılan cihaz: {device}")

df = pd.read_csv('dataset.csv')

labels = pd.read_csv("dataset.csv")
labels = labels["label"].values.tolist()
# Out:
# Kullanılan cihaz: cuda

# %%
import numpy as np
import pandas as pd
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torch.optim import AdamW
from transformers import AutoModel, AutoTokenizer, get_linear_schedule_with_warmup
from sklearn.metrics import f1_score, classification_report
from sklearn.model_selection import train_test_split
import os

tokenizer = AutoTokenizer.from_pretrained("dbmdz/bert-base-turkish-cased")
tokenizer2 = AutoTokenizer.from_pretrained("TURKCELL/roberta-base-turkish-uncased")


metinler = df["text"].values.tolist()

# Tokenize et ve attention mask'i al
#encodings = tokenizer(metinler, padding=True, truncation=True, return_tensors='pt')
# Tokenize et ve attention mask'i al
encodings = tokenizer2(
    metinler,
    padding=True,
    truncation=True,
    max_length=512,  # Bu satırı ekleyin
    return_tensors='pt'
)
input_ids = encodings['input_ids']
attention_mask = encodings['attention_mask']
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/385 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/251k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/650 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/976k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/634k [00:00<?, ?B/s]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import copy

class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2.0, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha  # Weight factor for each class
        self.gamma = gamma  # Focusing parameter
        self.reduction = reduction

    def forward(self, inputs, targets):
        log_softmax = F.log_softmax(inputs, dim=1)
        ce_loss = F.nll_loss(log_softmax, targets, weight=self.alpha, reduction='none')

        # Get the probabilities for the target class
        p_t = torch.exp(-ce_loss)

        # Apply the focusing term
        focal_loss = (1 - p_t) ** self.gamma * ce_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

# %%
# Sabit değerler
MAX_LEN = 128
BATCH_SIZE = 48
EPOCHS = 5
LEARNING_RATE = 2e-5
DROPOUT_RATE = 0.3
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
MODEL_NAME = "dbmdz/bert-base-turkish-cased"  # BERTurk modeli
MODEL_NAME2 = "TURKCELL/roberta-base-turkish-uncased"

# %%
class BERTurkBiLSTMEnsemble(nn.Module):
    def __init__(self, dropout_rate=DROPOUT_RATE, freeze=False):
        super(BERTurkBiLSTMEnsemble, self).__init__()
        self.bert = AutoModel.from_pretrained(MODEL_NAME2)
        self.dropout = nn.Dropout(dropout_rate)
        self.hidden_size = 128
        self.bilstm = nn.LSTM(
            input_size=self.bert.config.hidden_size,
            hidden_size=self.hidden_size,
            num_layers=1,
            batch_first=True,
            bidirectional=True
        )
        self.classifier = nn.Linear(self.hidden_size * 2, 2)  # Binary classification

        if freeze:
            for param in self.bert.parameters():
                param.requires_grad = False

    def forward(self, input_ids, attention_mask):
        # BERT encoding
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)

        # Get sequence output instead of just pooled output for LSTM
        sequence_output = outputs.last_hidden_state  # Shape: [batch_size, seq_len, hidden_size]
        sequence_output = self.dropout(sequence_output)

        # Pass through BiLSTM
        lstm_output, (hidden_state, cell_state) = self.bilstm(sequence_output)
        # lstm_output shape: [batch_size, seq_len, hidden_size*2]

        # Use the last hidden state of the BiLSTM for classification
        # Get the indices of the last tokens in each sequence based on attention mask
        last_token_indices = attention_mask.sum(dim=1) - 1

        # Gather the last hidden states for each sequence
        batch_size = lstm_output.shape[0]
        last_hidden_states = torch.zeros(batch_size, lstm_output.shape[2]).to(DEVICE)
        for i in range(batch_size):
            last_hidden_states[i] = lstm_output[i, last_token_indices[i], :]

        # Pass through final classifier
        logits = self.classifier(last_hidden_states)
        return logits

class CustomDataset(Dataset):
    def __init__(self, input_ids, attention_masks, labels=None):
        self.input_ids = input_ids
        self.attention_masks = attention_masks
        self.labels = labels

    def __len__(self):
        return len(self.input_ids)

    def __getitem__(self, idx):
        item = {
            'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
            'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
        }

        if self.labels is not None:
            item['labels'] = torch.tensor(self.labels[idx], dtype=torch.long)

        return item

class EarlyStoppingWithClassF1:
    def __init__(self, patience=5, min_delta=0.001, class_index=1, class_weight=0.5):
        """
        Early stopping that monitors both overall F1 and Class 1 F1 scores

        Args:
            patience: Number of epochs to wait before stopping
            min_delta: Minimum change in monitored metrics to qualify as improvement
            class_index: Index of the class to monitor (1 for Class 1)
            class_weight: Weight given to class F1 vs overall F1 (0.5 means equal weight)
        """
        self.patience = patience
        self.min_delta = min_delta
        self.class_index = class_index
        self.class_weight = class_weight
        self.counter = 0
        self.best_score = None
        self.best_class_f1 = None
        self.early_stop = False
        self.best_weights = None

    def __call__(self, model, val_overall_f1, val_class_f1s):
        """
        Args:
            model: Model to save if improvement
            val_overall_f1: Overall validation F1 score
            val_class_f1s: F1 scores for each class (list or array)
        """
        # Get the F1 score for the specific class we're monitoring
        class_f1 = val_class_f1s[self.class_index]

        # Calculate a combined score that considers both overall F1 and class F1
        combined_score = (1 - self.class_weight) * val_overall_f1 + self.class_weight * class_f1

        if self.best_score is None or self.best_class_f1 is None:
            # First epoch
            self.best_score = combined_score
            self.best_class_f1 = class_f1
            self.save_checkpoint(model)
        elif combined_score < self.best_score + self.min_delta:
            # Score didn't improve enough
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            # Score improved, but also check if Class 1 F1 didn't decrease significantly
            class_f1_decrease = self.best_class_f1 - class_f1

            # Only consider it an improvement if Class 1 F1 didn't drop too much
            if class_f1_decrease <= self.min_delta:
                print(f'Validation score improved! Overall F1: {val_overall_f1:.4f}, Class 1 F1: {class_f1:.4f}')
                self.best_score = combined_score
                self.best_class_f1 = class_f1
                self.save_checkpoint(model)
                self.counter = 0
            else:
                # Class 1 F1 dropped too much, don't reset counter
                print(f'Overall score improved but Class 1 F1 dropped too much (from {self.best_class_f1:.4f} to {class_f1:.4f})')
                self.counter += 1
                if self.counter >= self.patience:
                    self.early_stop = True

    def save_checkpoint(self, model):
        """Save model weights when validation performance improves"""
        self.best_weights = copy.deepcopy(model.state_dict())

    def restore_best_weights(self, model):
        """Restore model to best weights"""
        model.load_state_dict(self.best_weights)

def train_model(model, train_dataloader, test_dataloader=None, class_weights=None, gamma=2.0,
                num_epochs=10, patience=3, class_f1_weight=0.6, learning_rate=2e-5):
    """
    Train model with Focal Loss and balanced early stopping

    Args:
        model: Model to train
        train_dataloader: Training data loader
        test_dataloader: Validation/test data loader
        class_weights: Dictionary mapping class indices to weights (e.g., {0: 1, 1: 6})
        gamma: Focal loss focusing parameter
        num_epochs: Maximum number of training epochs
        patience: Early stopping patience
        class_f1_weight: Weight to give to Class 1 F1 score in early stopping
        learning_rate: Learning rate for optimizer

    Returns:
        trained_model: The trained model
        history: Dictionary containing training metrics
    """
    # Set up device
    device = next(model.parameters()).device

    # Create alpha tensor for focal loss based on class weights
    if class_weights is not None:
        num_classes = len(class_weights)
        alpha = torch.ones(num_classes)
        for cls_idx, weight in class_weights.items():
            alpha[cls_idx] = weight
        alpha = alpha.to(device)
    else:
        alpha = None

    # Initialize Focal Loss
    criterion = FocalLoss(alpha=alpha, gamma=gamma)

    # Initialize optimizer
    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

    # Set up early stopping
    early_stopping = EarlyStoppingWithClassF1(
        patience=patience,
        class_index=1,  # Monitor Class 1 F1
        class_weight=class_f1_weight
    )

    # Track metrics
    history = {
        'train_loss': [],
        'train_f1': [],
        'train_class_f1s': [],
        'val_loss': [],
        'val_f1': [],
        'val_class_f1s': []
    }

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        train_preds = []
        train_labels = []

        for batch in train_dataloader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            # Forward pass
            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            loss = criterion(outputs, labels)

            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

            # Store predictions and labels for metrics
            _, preds = torch.max(outputs, 1)
            train_preds.extend(preds.cpu().numpy())
            train_labels.extend(labels.cpu().numpy())

        # Calculate training metrics
        train_loss = train_loss / len(train_dataloader)
        train_f1 = f1_score(train_labels, train_preds, average='weighted')
        train_class_f1s = f1_score(train_labels, train_preds, average=None)

        # Save training metrics
        history['train_loss'].append(train_loss)
        history['train_f1'].append(train_f1)
        history['train_class_f1s'].append(train_class_f1s.tolist())

        # Validation phase
        if test_dataloader is not None:
            model.eval()
            val_loss = 0.0
            val_preds = []
            val_labels = []

            with torch.no_grad():
                for batch in test_dataloader:
                    input_ids = batch['input_ids'].to(device)
                    attention_mask = batch['attention_mask'].to(device)
                    labels = batch['labels'].to(device)

                    # Forward pass
                    outputs = model(input_ids=input_ids, attention_mask=attention_mask)
                    loss = criterion(outputs, labels)

                    val_loss += loss.item()

                    # Store predictions and labels for metrics
                    _, preds = torch.max(outputs, 1)
                    val_preds.extend(preds.cpu().numpy())
                    val_labels.extend(labels.cpu().numpy())

            # Calculate validation metrics
            val_loss = val_loss / len(test_dataloader)
            val_f1 = f1_score(val_labels, val_preds, average='weighted')
            val_class_f1s = f1_score(val_labels, val_preds, average=None)

            # Save validation metrics
            history['val_loss'].append(val_loss)
            history['val_f1'].append(val_f1)
            history['val_class_f1s'].append(val_class_f1s.tolist())

            # Print epoch results
            print(f'Epoch {epoch+1}/{num_epochs}')
            print(f'Train Loss: {train_loss:.4f}, Train F1: {train_f1:.4f}, Train Class 1 F1: {train_class_f1s[1]:.4f}')
            print(f'Val Loss: {val_loss:.4f}, Val F1: {val_f1:.4f}, Val Class 1 F1: {val_class_f1s[1]:.4f}')

            # Early stopping check
            early_stopping(model, val_f1, val_class_f1s)

            if early_stopping.early_stop:
                print("Early stopping triggered")
                # Restore best weights
                early_stopping.restore_best_weights(model)
                break
        else:
            # Print training metrics when no validation set provided
            print(f'Epoch {epoch+1}/{num_epochs}')
            print(f'Train Loss: {train_loss:.4f}, Train F1: {train_f1:.4f}, Train Class 1 F1: {train_class_f1s[1]:.4f}')

    # Load best weights if early stopping was used
    if test_dataloader is not None and early_stopping.best_weights is not None:
        model.load_state_dict(early_stopping.best_weights)

    return model, history

# Partially freeze BERT (freeze only the first N layers)
def freeze_bert_layers(model, num_layers_to_freeze):
    # Freeze embeddings
    for param in model.bert.embeddings.parameters():
        param.requires_grad = False

    # Freeze the first num_layers_to_freeze encoder layers
    for layer in list(model.bert.encoder.layer)[:num_layers_to_freeze]:
        for param in layer.parameters():
            param.requires_grad = False


def train_model1(model, train_dataloader, test_dataloader=None, class_weights=None, gamma=2.0):
    """Modeli eğitme ve metrikleri kaydetme"""
    # Optimizer ve scheduler oluştur
    optimizer = AdamW([p for p in model.parameters() if p.requires_grad], lr=LEARNING_RATE)
    total_steps = len(train_dataloader) * EPOCHS
    scheduler = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps=0,
        num_training_steps=total_steps
    )

    # Focal Loss fonksiyonu - class weights kullanarak dengesiz veri için
    if class_weights is not None:
        weights = torch.tensor(list(class_weights.values())).float().to(DEVICE)
        loss_fn = FocalLoss(alpha=weights, gamma=gamma)
    else:
        loss_fn = FocalLoss(gamma=gamma)

    # Eğitim metriklerini kaydetmek için history sözlüğü
    history = {
        "train_loss": [], "train_f1": [], "train_acc": [],
        "train_class_0_acc": [], "train_class_1_acc": []
    }

    if test_dataloader:
        history.update({
            "test_loss": [], "test_f1": [], "test_acc": [],
            "test_class_0_acc": [], "test_class_1_acc": []
        })

    # Eğitim döngüsü
    best_train_f1 = 0
    for epoch in range(EPOCHS):
        print(f"\n{'='*50}")
        print(f"Epoch {epoch+1}/{EPOCHS}")
        print(f"{'='*50}")

        # Eğitim aşaması
        model.train()
        train_predictions = []
        train_true_labels = []
        train_loss = 0

        for batch in train_dataloader:
            input_ids = batch['input_ids'].to(DEVICE)
            attention_mask = batch['attention_mask'].to(DEVICE)
            labels = batch['labels'].to(DEVICE)

            optimizer.zero_grad()
            outputs = model(input_ids, attention_mask)
            loss = loss_fn(outputs, labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            scheduler.step()

            train_loss += loss.item()

            # Training performans hesaplaması için tahminleri topla
            _, preds = torch.max(outputs, dim=1)
            train_predictions.extend(preds.cpu().tolist())
            train_true_labels.extend(labels.cpu().tolist())

        # Eğitim metriklerini hesapla
        train_metrics = calculate_metrics(train_true_labels, train_predictions)
        train_metrics["loss"] = train_loss / len(train_dataloader)

        # Test metriklerini hesapla (eğer test_dataloader verilmişse)
        if test_dataloader:
            test_metrics = evaluate_model(model, test_dataloader, loss_fn)

        # Metrikleri history'e kaydet
        history["train_loss"].append(train_metrics["loss"])
        history["train_f1"].append(train_metrics["f1_weighted"])
        history["train_acc"].append(train_metrics["accuracy"])
        history["train_class_0_acc"].append(train_metrics["class_0_acc"])
        history["train_class_1_acc"].append(train_metrics["class_1_acc"])

        if test_dataloader:
            history["test_loss"].append(test_metrics["loss"])
            history["test_f1"].append(test_metrics["f1_weighted"])
            history["test_acc"].append(test_metrics["accuracy"])
            history["test_class_0_acc"].append(test_metrics["class_0_acc"])
            history["test_class_1_acc"].append(test_metrics["class_1_acc"])

        # Metrikleri yazdır
        print_metrics(train_metrics, "Training")
        if test_dataloader:
            print_metrics(test_metrics, "Test")

        # En iyi modeli kaydet (F1 metriğine göre)
        if train_metrics["f1_weighted"] > best_train_f1:
            best_train_f1 = train_metrics["f1_weighted"]
            torch.save(model.state_dict(), 'best_berturk_bigru.pt')
            print(f"\nModel kaydedildi! En iyi Training F1 Skor: {best_train_f1:.4f}")

    # Eğitim sonrası grafikleri çiz
    plot_training_history(history)

    return model, history


def calculate_metrics(y_true, y_pred):
    """
    Hesaplanan metrikleri döndür:
    - F1 skoru (weighted)
    - Accuracy
    - Her sınıf için precision, recall ve f1
    """
    # Genel metrikler
    f1 = f1_score(y_true, y_pred, average='weighted')
    acc = accuracy_score(y_true, y_pred)

    # Sınıf bazlı metrikler
    class_report = classification_report(y_true, y_pred, output_dict=True)

    # Confusion Matrix
    cm = confusion_matrix(y_true, y_pred)

    # Sınıf bazlı accuracy hesaplama
    class_accuracies = {}
    for cls in set(y_true):
        # Belirli bir sınıfa ait örneklerin indexleri
        class_idx = [i for i, label in enumerate(y_true) if label == cls]
        # Bu örnekler için doğru tahmin sayısı
        correct_preds = sum(1 for i in class_idx if y_pred[i] == y_true[i])
        # Sınıf accuracy'si
        class_accuracies[f"class_{cls}_acc"] = correct_preds / len(class_idx) if len(class_idx) > 0 else 0

    metrics = {
        "f1_weighted": f1,
        "accuracy": acc,
        **class_accuracies,
        "confusion_matrix": cm,
        "classification_report": class_report
    }

    return metrics


def evaluate_model(model, dataloader, criterion=None):
    """
    Evaluate model performance

    Args:
        model: Trained model to evaluate
        dataloader: Data loader for evaluation
        criterion: Loss function (optional)

    Returns:
        metrics: Dictionary containing evaluation metrics
    """
    device = next(model.parameters()).device
    model.eval()

    all_preds = []
    all_labels = []
    total_loss = 0.0

    with torch.no_grad():
        for batch in dataloader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['labels'].to(device)

            # Forward pass
            outputs = model(input_ids=input_ids, attention_mask=attention_mask)

            # Calculate loss if criterion provided
            if criterion is not None:
                loss = criterion(outputs, labels)
                total_loss += loss.item()

            # Get predictions
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Calculate metrics
    from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, precision_score, recall_score

    metrics = {
        'accuracy': accuracy_score(all_labels, all_preds),
        'f1_weighted': f1_score(all_labels, all_preds, average='weighted'),
        'f1_macro': f1_score(all_labels, all_preds, average='macro'),
        'f1_by_class': f1_score(all_labels, all_preds, average=None),
        'precision_weighted': precision_score(all_labels, all_preds, average='weighted'),
        'recall_weighted': recall_score(all_labels, all_preds, average='weighted'),
        'confusion_matrix': confusion_matrix(all_labels, all_preds).tolist(),
        'classification_report': classification_report(all_labels, all_preds, output_dict=True)
    }

    # Add loss if criterion was provided
    if criterion is not None:
        metrics['loss'] = total_loss / len(dataloader)

    # Print key metrics
    print(f"Evaluation Results:")
    print(f"Accuracy: {metrics['accuracy']:.4f}")
    print(f"F1 Score (Weighted): {metrics['f1_weighted']:.4f}")
    print(f"F1 Score for Class 1: {metrics['f1_by_class'][1]:.4f}")
    print(f"Confusion Matrix:\n{metrics['confusion_matrix']}")

    return metrics


def evaluate_model1(model, dataloader, loss_fn):
    """Modeli değerlendirme"""
    model.eval()
    predictions = []
    true_labels = []
    total_loss = 0

    with torch.no_grad():
        for batch in dataloader:
            input_ids = batch['input_ids'].to(DEVICE)
            attention_mask = batch['attention_mask'].to(DEVICE)
            labels = batch['labels'].to(DEVICE)

            outputs = model(input_ids, attention_mask)
            loss = loss_fn(outputs, labels)
            total_loss += loss.item()

            _, preds = torch.max(outputs, dim=1)

            predictions.extend(preds.cpu().tolist())
            true_labels.extend(labels.cpu().tolist())

    # Metrikleri hesapla
    metrics = calculate_metrics(true_labels, predictions)
    metrics["loss"] = total_loss / len(dataloader)

    return metrics


def print_metrics(metrics, set_name=""):
    """Metrikleri düzenli bir şekilde yazdır"""
    print(f"\n{set_name} Metrikleri:")
    print(f"Loss: {metrics['loss']:.4f}")
    print(f"F1 Score (Weighted): {metrics['f1_weighted']:.4f}")
    print(f"Accuracy: {metrics['accuracy']:.4f}")

    # Sınıf bazlı accuracy'leri yazdır
    for key, value in metrics.items():
        if key.startswith("class_"):
            print(f"{key}: {value:.4f}")

    # Classification report'u düzenli yazdır
    print("\nSınıf Bazlı Detaylı Metrikler:")
    for cls, metrics_dict in metrics["classification_report"].items():
        if cls in ['0', '1']:  # Sadece sınıf metriklerini göster
            print(f"  Sınıf {cls}:")
            print(f"    Precision: {metrics_dict['precision']:.4f}")
            print(f"    Recall: {metrics_dict['recall']:.4f}")
            print(f"    F1-score: {metrics_dict['f1-score']:.4f}")
            print(f"    Support: {metrics_dict['support']}")

    print("\nConfusion Matrix:")
    print(metrics["confusion_matrix"])


def plot_training_history(history):
    """Eğitim sürecindeki metriklerin grafiklerini çiz"""
    epochs = range(1, len(history["train_loss"]) + 1)

    # Eğer test_loss yoksa, sadece train metriklerini çizdir
    has_test = "test_loss" in history

    # Loss grafiği
    plt.figure(figsize=(12, 8))
    plt.subplot(2, 2, 1)
    plt.plot(epochs, history["train_loss"], 'b-', label='Training Loss')
    if has_test:
        plt.plot(epochs, history["test_loss"], 'g-', label='Test Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # F1 grafiği
    plt.subplot(2, 2, 2)
    plt.plot(epochs, history["train_f1"], 'b-', label='Training F1')
    if has_test:
        plt.plot(epochs, history["test_f1"], 'g-', label='Test F1')
    plt.title('F1 Score')
    plt.xlabel('Epochs')
    plt.ylabel('F1 Score')
    plt.legend()

    # Accuracy grafiği
    plt.subplot(2, 2, 3)
    plt.plot(epochs, history["train_acc"], 'b-', label='Training Accuracy')
    if has_test:
        plt.plot(epochs, history["test_acc"], 'g-', label='Test Accuracy')
    plt.title('Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Sınıf 1 Accuracy grafiği
    plt.subplot(2, 2, 4)
    plt.plot(epochs, history["train_class_1_acc"], 'b-', label='Training Class 1 Acc')
    if has_test:
        plt.plot(epochs, history["test_class_1_acc"], 'g-', label='Test Class 1 Acc')
    plt.title('Class 1 Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()
    plt.savefig('training_history.png')
    plt.show()



train_inputs, test_inputs, train_masks, test_masks, train_labels, test_labels = train_test_split(
    input_ids, attention_mask, labels, test_size=0.2, random_state=42, stratify=labels
)

# Dataset ve DataLoader oluşturma
train_dataset = CustomDataset(train_inputs, train_masks, train_labels)
test_dataset = CustomDataset(test_inputs, test_masks, test_labels)

train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

# Model oluşturma
model = BERTurkBiLSTMEnsemble(freeze=False).to(DEVICE)  # Don't freeze everything
#freeze_bert_layers(model, num_layers_to_freeze=8)  # Freeze the first 8 layers

# Sınıf ağırlığı ve Focal Loss parametreleri
class_weights = {0: 1, 1: 6}  # veya None
gamma = 2.0  # Focal Loss focusing parametresi

# Modeli eğitme (Focal Loss ve dengeli early stopping kullanarak)
trained_model, history = train_model(
    model=model,
    train_dataloader=train_dataloader,
    test_dataloader=test_dataloader,
    class_weights=class_weights,
    gamma=gamma,
    patience=3,            # Early stopping için sabır değeri
    class_f1_weight=0.6    # Sınıf 1 F1 skoru ağırlığı (daha yüksek değer = sınıf 1'e daha fazla önem)
)

# Son test değerlendirmesi - Focal Loss ile
focal_loss = FocalLoss(
    alpha=torch.tensor([1, 6]).float().to(DEVICE),
    gamma=gamma
)
test_metrics = evaluate_model(trained_model, test_dataloader, focal_loss)

# Sonuçları görüntüleme
print(f"Test Metrics:")
print(f"Overall F1 score: {test_metrics['f1_weighted']:.4f}")
print(f"Class 1 F1 score: {test_metrics['f1_by_class'][1]:.4f}")
# Out:
# pytorch_model.bin:   0%|          | 0.00/499M [00:00<?, ?B/s]
# Some weights of RobertaModel were not initialized from the model checkpoint at TURKCELL/roberta-base-turkish-uncased and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# model.safetensors:   0%|          | 0.00/499M [00:00<?, ?B/s]
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# Epoch 1/10
# Train Loss: 0.5046, Train F1: 0.5675, Train Class 1 F1: 0.3857
# Val Loss: 0.3874, Val F1: 0.7752, Val Class 1 F1: 0.5347
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# Epoch 2/10
# Train Loss: 0.3294, Train F1: 0.8233, Train Class 1 F1: 0.5990
# Val Loss: 0.3497, Val F1: 0.8509, Val Class 1 F1: 0.6289
# Validation score improved! Overall F1: 0.8509, Class 1 F1: 0.6289
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# Epoch 3/10
# Train Loss: 0.2533, Train F1: 0.8707, Train Class 1 F1: 0.6787
# Val Loss: 0.3798, Val F1: 0.8707, Val Class 1 F1: 0.6553
# Validation score improved! Overall F1: 0.8707, Class 1 F1: 0.6553
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# Epoch 4/10
# Train Loss: 0.2025, Train F1: 0.8956, Train Class 1 F1: 0.7303
# Val Loss: 0.3596, Val F1: 0.8677, Val Class 1 F1: 0.6564
# EarlyStopping counter: 1 out of 3
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# Epoch 5/10
# Train Loss: 0.1707, Train F1: 0.9132, Train Class 1 F1: 0.7695
# Val Loss: 0.4167, Val F1: 0.8697, Val Class 1 F1: 0.6592
# Validation score improved! Overall F1: 0.8697, Class 1 F1: 0.6592
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# Epoch 6/10
# Train Loss: 0.1359, Train F1: 0.9321, Train Class 1 F1: 0.8135
# Val Loss: 0.4009, Val F1: 0.8684, Val Class 1 F1: 0.6584
# EarlyStopping counter: 1 out of 3
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# Epoch 7/10
# Train Loss: 0.1067, Train F1: 0.9479, Train Class 1 F1: 0.8530
# Val Loss: 0.5372, Val F1: 0.9019, Val Class 1 F1: 0.7121
# Validation score improved! Overall F1: 0.9019, Class 1 F1: 0.7121
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# Epoch 8/10
# Train Loss: 0.0917, Train F1: 0.9554, Train Class 1 F1: 0.8728
# Val Loss: 0.6570, Val F1: 0.9039, Val Class 1 F1: 0.7140
# Validation score improved! Overall F1: 0.9039, Class 1 F1: 0.7140
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),
# Epoch 9/10
# Train Loss: 0.0787, Train F1: 0.9607, Train Class 1 F1: 0.8871
# Val Loss: 0.7290, Val F1: 0.9004, Val Class 1 F1: 0.7047
# EarlyStopping counter: 1 out of 3
# <ipython-input-5-1bc1d8cd458e>:57: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'input_ids': torch.tensor(self.input_ids[idx], dtype=torch.long),
# <ipython-input-5-1bc1d8cd458e>:58: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'attention_mask': torch.tensor(self.attention_masks[idx], dtype=torch.long),

# %%
#modelin ağırlıklarını kaydet

torch.save(trained_model.state_dict(), 'best_berturk_bilstm_roberta.pt')

# %%
best_test_metrics = evaluate_model1(trained_model, test_dataloader, focal_loss)
print("\nEn İyi Modelin Test Metrikleri:")
print_metrics(best_test_metrics, "Test")

# %%
import numpy as np
import pandas as pd
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer
from torch.optim import AdamW
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score
import copy
import math
import joblib

# Cuda kontrolü
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Kullanılan cihaz: {device}")

# Sabit değerler
BATCH_SIZE = 96
EPOCHS = 5
LEARNING_RATE = 2e-5
DROPOUT_RATE = 0.3
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
MAX_FEATURES = 5000  # TF-IDF için maksimum özellik sayısı
EMBEDDING_DIM = 128   # TF-IDF vektörlerinin projection boyutu
SEQ_LENGTH = 50      # TF-IDF vektörünün kaç parçaya bölüneceği

class TFIDFBiLSTMEnsemble(nn.Module):
    def __init__(self, input_size, seq_length=SEQ_LENGTH, embedding_dim=EMBEDDING_DIM, dropout_rate=DROPOUT_RATE):
        super(TFIDFBiLSTMEnsemble, self).__init__()

        # TF-IDF özelliklerini daha küçük boyutlu bir embeddings'e projeksiyon yapar
        self.projection = nn.Linear(input_size, embedding_dim * seq_length)

        # Kullanılacak sequence uzunluğu
        self.seq_length = seq_length
        self.embedding_dim = embedding_dim

        # BiLSTM katmanı
        self.bilstm = nn.LSTM(
            input_size=embedding_dim,
            hidden_size=128,
            num_layers=1,
            batch_first=True,
            bidirectional=True
        )

        # Dropout katmanı
        self.dropout = nn.Dropout(dropout_rate)

        # Son sınıflandırıcı katman
        self.classifier = nn.Linear(128 * 2, 2)  # BiLSTM çıktısı 2*hidden_size

    def forward(self, tfidf_features):
        batch_size = tfidf_features.size(0)

        # TF-IDF özelliklerini projeksiyon ile daha büyük bir vektöre dönüştür
        projected = self.projection(tfidf_features)  # [batch_size, embedding_dim*seq_length]

        # Projeksiyon çıktısını sequence formuna dönüştür
        # [batch_size, seq_length, embedding_dim]
        sequence = projected.view(batch_size, self.seq_length, self.embedding_dim)

        # BiLSTM katmanından geçir
        lstm_output, (hidden_state, cell_state) = self.bilstm(sequence)
        # lstm_output: [batch_size, seq_length, 2*hidden_size]

        # Son sequence elemanının çıktısını al
        # Son elemanı kullanabilir veya attention mekanizması ile ağırlıklı toplam alabilirsiniz
        last_output = lstm_output[:, -1, :]  # [batch_size, 2*hidden_size]

        # Dropout uygula
        last_output = self.dropout(last_output)

        # Sınıflandırıcıdan geçir
        logits = self.classifier(last_output)

        return logits

class TFIDFBiLSTMWithAttention(nn.Module):
    """
    TF-IDF özelliklerini kullanan ve attention mekanizmasına sahip BiLSTM modeli.
    Bu model, LSTM çıktılarını ağırlıklandırarak daha etkili özellik çıkarımı yapar.
    """
    def __init__(self, input_size, seq_length=SEQ_LENGTH, embedding_dim=EMBEDDING_DIM, dropout_rate=DROPOUT_RATE):
        super(TFIDFBiLSTMWithAttention, self).__init__()

        # TF-IDF özelliklerini daha küçük boyutlu bir embeddings'e projeksiyon yapar
        self.projection = nn.Linear(input_size, embedding_dim * seq_length)

        # Kullanılacak sequence uzunluğu
        self.seq_length = seq_length
        self.embedding_dim = embedding_dim
        self.hidden_size = 128

        # BiLSTM katmanı
        self.bilstm = nn.LSTM(
            input_size=embedding_dim,
            hidden_size=self.hidden_size,
            num_layers=1,
            batch_first=True,
            bidirectional=True
        )

        # Attention mechanism
        self.attention = nn.Linear(self.hidden_size * 2, 1)

        # Dropout katmanı
        self.dropout = nn.Dropout(dropout_rate)

        # Son sınıflandırıcı katman
        self.classifier = nn.Linear(self.hidden_size * 2, 2)  # BiLSTM çıktısı 2*hidden_size

    def forward(self, tfidf_features):
        batch_size = tfidf_features.size(0)

        # TF-IDF özelliklerini projeksiyon ile daha büyük bir vektöre dönüştür
        projected = self.projection(tfidf_features)  # [batch_size, embedding_dim*seq_length]

        # Projeksiyon çıktısını sequence formuna dönüştür
        # [batch_size, seq_length, embedding_dim]
        sequence = projected.view(batch_size, self.seq_length, self.embedding_dim)

        # BiLSTM katmanından geçir
        lstm_output, (hidden_state, cell_state) = self.bilstm(sequence)
        # lstm_output: [batch_size, seq_length, 2*hidden_size]

        # Attention weights hesapla
        # [batch_size, seq_length, 1]
        attention_weights = F.softmax(self.attention(lstm_output), dim=1)

        # Attention weights ile ağırlıklı toplam al
        # [batch_size, 2*hidden_size]
        attention_output = torch.sum(attention_weights * lstm_output, dim=1)

        # Dropout uygula
        attention_output = self.dropout(attention_output)

        # Sınıflandırıcıdan geçir
        logits = self.classifier(attention_output)

        return logits

class CustomTFIDFDataset(Dataset):
    def __init__(self, tfidf_features, labels=None):
        self.tfidf_features = tfidf_features
        self.labels = labels

    def __len__(self):
        return len(self.tfidf_features)

    def __getitem__(self, idx):
        item = {
            'tfidf_features': torch.tensor(self.tfidf_features[idx], dtype=torch.float)
        }

        if self.labels is not None:
            item['labels'] = torch.tensor(self.labels[idx], dtype=torch.long)

        return item

class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2.0, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha  # Weight factor for each class
        self.gamma = gamma  # Focusing parameter
        self.reduction = reduction

    def forward(self, inputs, targets):
        log_softmax = nn.functional.log_softmax(inputs, dim=1)
        ce_loss = nn.functional.nll_loss(log_softmax, targets, weight=self.alpha, reduction='none')

        # Get the probabilities for the target class
        p_t = torch.exp(-ce_loss)

        # Apply the focusing term
        focal_loss = (1 - p_t) ** self.gamma * ce_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

class EarlyStoppingWithClassF1:
    def __init__(self, patience=5, min_delta=0.001, class_index=1, class_weight=0.5):
        """
        Early stopping that monitors both overall F1 and Class 1 F1 scores

        Args:
            patience: Number of epochs to wait before stopping
            min_delta: Minimum change in monitored metrics to qualify as improvement
            class_index: Index of the class to monitor (1 for Class 1)
            class_weight: Weight given to class F1 vs overall F1 (0.5 means equal weight)
        """
        self.patience = patience
        self.min_delta = min_delta
        self.class_index = class_index
        self.class_weight = class_weight
        self.counter = 0
        self.best_score = None
        self.best_class_f1 = None
        self.early_stop = False
        self.best_weights = None

    def __call__(self, model, val_overall_f1, val_class_f1s):
        """
        Args:
            model: Model to save if improvement
            val_overall_f1: Overall validation F1 score
            val_class_f1s: F1 scores for each class (list or array)
        """
        # Get the F1 score for the specific class we're monitoring
        class_f1 = val_class_f1s[self.class_index]

        # Calculate a combined score that considers both overall F1 and class F1
        combined_score = (1 - self.class_weight) * val_overall_f1 + self.class_weight * class_f1

        if self.best_score is None or self.best_class_f1 is None:
            # First epoch
            self.best_score = combined_score
            self.best_class_f1 = class_f1
            self.save_checkpoint(model)
        elif combined_score < self.best_score + self.min_delta:
            # Score didn't improve enough
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            # Score improved, but also check if Class 1 F1 didn't decrease significantly
            class_f1_decrease = self.best_class_f1 - class_f1

            # Only consider it an improvement if Class 1 F1 didn't drop too much
            if class_f1_decrease <= self.min_delta:
                print(f'Validation score improved! Overall F1: {val_overall_f1:.4f}, Class 1 F1: {class_f1:.4f}')
                self.best_score = combined_score
                self.best_class_f1 = class_f1
                self.save_checkpoint(model)
                self.counter = 0
            else:
                # Class 1 F1 dropped too much, don't reset counter
                print(f'Overall score improved but Class 1 F1 dropped too much (from {self.best_class_f1:.4f} to {class_f1:.4f})')
                self.counter += 1
                if self.counter >= self.patience:
                    self.early_stop = True

    def save_checkpoint(self, model):
        """Save model weights when validation performance improves"""
        self.best_weights = copy.deepcopy(model.state_dict())

    def restore_best_weights(self, model):
        """Restore model to best weights"""
        model.load_state_dict(self.best_weights)

def train_model(model, train_dataloader, test_dataloader=None, class_weights=None, gamma=2.0,
                num_epochs=10, patience=3, class_f1_weight=0.6, learning_rate=2e-5):
    """
    Train model with Focal Loss and balanced early stopping

    Args:
        model: Model to train
        train_dataloader: Training data loader
        test_dataloader: Validation/test data loader
        class_weights: Dictionary mapping class indices to weights (e.g., {0: 1, 1: 6})
        gamma: Focal loss focusing parameter
        num_epochs: Maximum number of training epochs
        patience: Early stopping patience
        class_f1_weight: Weight to give to Class 1 F1 score in early stopping
        learning_rate: Learning rate for optimizer

    Returns:
        trained_model: The trained model
        history: Dictionary containing training metrics
    """
    # Set up device
    device = next(model.parameters()).device

    # Create alpha tensor for focal loss based on class weights
    if class_weights is not None:
        num_classes = len(class_weights)
        alpha = torch.ones(num_classes)
        for cls_idx, weight in class_weights.items():
            alpha[cls_idx] = weight
        alpha = alpha.to(device)
    else:
        alpha = None

    # Initialize Focal Loss
    criterion = FocalLoss(alpha=alpha, gamma=gamma)

    # Initialize optimizer
    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

    # Set up early stopping
    early_stopping = EarlyStoppingWithClassF1(
        patience=patience,
        class_index=1,  # Monitor Class 1 F1
        class_weight=class_f1_weight
    )

    # Track metrics
    history = {
        'train_loss': [],
        'train_f1': [],
        'train_class_f1s': [],
        'val_loss': [],
        'val_f1': [],
        'val_class_f1s': []
    }

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        train_preds = []
        train_labels = []

        for batch in train_dataloader:
            tfidf_features = batch['tfidf_features'].to(device)
            labels = batch['labels'].to(device)

            # Forward pass
            outputs = model(tfidf_features)
            loss = criterion(outputs, labels)

            # Backward and optimize
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

            # Store predictions and labels for metrics
            _, preds = torch.max(outputs, 1)
            train_preds.extend(preds.cpu().numpy())
            train_labels.extend(labels.cpu().numpy())

        # Calculate training metrics
        train_loss = train_loss / len(train_dataloader)
        train_f1 = f1_score(train_labels, train_preds, average='weighted')
        train_class_f1s = f1_score(train_labels, train_preds, average=None)

        # Save training metrics
        history['train_loss'].append(train_loss)
        history['train_f1'].append(train_f1)
        history['train_class_f1s'].append(train_class_f1s.tolist())

        # Validation phase
        if test_dataloader is not None:
            model.eval()
            val_loss = 0.0
            val_preds = []
            val_labels = []

            with torch.no_grad():
                for batch in test_dataloader:
                    tfidf_features = batch['tfidf_features'].to(device)
                    labels = batch['labels'].to(device)

                    # Forward pass
                    outputs = model(tfidf_features)
                    loss = criterion(outputs, labels)

                    val_loss += loss.item()

                    # Store predictions and labels for metrics
                    _, preds = torch.max(outputs, 1)
                    val_preds.extend(preds.cpu().numpy())
                    val_labels.extend(labels.cpu().numpy())

            # Calculate validation metrics
            val_loss = val_loss / len(test_dataloader)
            val_f1 = f1_score(val_labels, val_preds, average='weighted')
            val_class_f1s = f1_score(val_labels, val_preds, average=None)

            # Save validation metrics
            history['val_loss'].append(val_loss)
            history['val_f1'].append(val_f1)
            history['val_class_f1s'].append(val_class_f1s.tolist())

            # Print epoch results
            print(f'Epoch {epoch+1}/{num_epochs}')
            print(f'Train Loss: {train_loss:.4f}, Train F1: {train_f1:.4f}, Train Class 1 F1: {train_class_f1s[1]:.4f}')
            print(f'Val Loss: {val_loss:.4f}, Val F1: {val_f1:.4f}, Val Class 1 F1: {val_class_f1s[1]:.4f}')

            # Early stopping check
            early_stopping(model, val_f1, val_class_f1s)

            if early_stopping.early_stop:
                print("Early stopping triggered")
                # Restore best weights
                early_stopping.restore_best_weights(model)
                break
        else:
            # Print training metrics when no validation set provided
            print(f'Epoch {epoch+1}/{num_epochs}')
            print(f'Train Loss: {train_loss:.4f}, Train F1: {train_f1:.4f}, Train Class 1 F1: {train_class_f1s[1]:.4f}')

    # Load best weights if early stopping was used
    if test_dataloader is not None and early_stopping.best_weights is not None:
        model.load_state_dict(early_stopping.best_weights)

    return model, history

def evaluate_model(model, dataloader, criterion=None):
    """
    Evaluate model performance

    Args:
        model: Trained model to evaluate
        dataloader: Data loader for evaluation
        criterion: Loss function (optional)

    Returns:
        metrics: Dictionary containing evaluation metrics
    """
    device = next(model.parameters()).device
    model.eval()

    all_preds = []
    all_labels = []
    total_loss = 0.0

    with torch.no_grad():
        for batch in dataloader:
            tfidf_features = batch['tfidf_features'].to(device)
            labels = batch['labels'].to(device)

            # Forward pass
            outputs = model(tfidf_features)

            # Calculate loss if criterion provided
            if criterion is not None:
                loss = criterion(outputs, labels)
                total_loss += loss.item()

            # Get predictions
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Calculate metrics
    from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, precision_score, recall_score

    metrics = {
        'accuracy': accuracy_score(all_labels, all_preds),
        'f1_weighted': f1_score(all_labels, all_preds, average='weighted'),
        'f1_macro': f1_score(all_labels, all_preds, average='macro'),
        'f1_by_class': f1_score(all_labels, all_preds, average=None),
        'precision_weighted': precision_score(all_labels, all_preds, average='weighted'),
        'recall_weighted': recall_score(all_labels, all_preds, average='weighted'),
        'confusion_matrix': confusion_matrix(all_labels, all_preds).tolist(),
        'classification_report': classification_report(all_labels, all_preds, output_dict=True)
    }

    # Add loss if criterion was provided
    if criterion is not None:
        metrics['loss'] = total_loss / len(dataloader)

    # Print key metrics
    print(f"Evaluation Results:")
    print(f"Accuracy: {metrics['accuracy']:.4f}")
    print(f"F1 Score (Weighted): {metrics['f1_weighted']:.4f}")
    print(f"F1 Score for Class 1: {metrics['f1_by_class'][1]:.4f}")
    print(f"Confusion Matrix:\n{metrics['confusion_matrix']}")

    return metrics

def plot_training_history(history):
    """Eğitim sürecindeki metriklerin grafiklerini çiz"""
    epochs = range(1, len(history["train_loss"]) + 1)

    # Eğer val_loss yoksa, sadece train metriklerini çizdir
    has_val = "val_loss" in history and len(history["val_loss"]) > 0

    # Loss grafiği
    plt.figure(figsize=(16, 12))

    plt.subplot(2, 2, 1)
    plt.plot(epochs, history["train_loss"], 'b-', label='Training Loss')
    if has_val:
        plt.plot(epochs, history["val_loss"], 'r-', label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    # F1 grafiği
    plt.subplot(2, 2, 2)
    plt.plot(epochs, history["train_f1"], 'b-', label='Training F1')
    if has_val:
        plt.plot(epochs, history["val_f1"], 'r-', label='Validation F1')
    plt.title('F1 Score (Weighted)')
    plt.xlabel('Epochs')
    plt.ylabel('F1 Score')
    plt.legend()

    # Class F1 grafiği - sınıf 0
    plt.subplot(2, 2, 3)
    train_class_0_f1 = [f1s[0] for f1s in history["train_class_f1s"]]
    plt.plot(epochs, train_class_0_f1, 'b-', label='Training Class 0 F1')
    if has_val:
        val_class_0_f1 = [f1s[0] for f1s in history["val_class_f1s"]]
        plt.plot(epochs, val_class_0_f1, 'r-', label='Validation Class 0 F1')
    plt.title('Class 0 F1 Score')
    plt.xlabel('Epochs')
    plt.ylabel('F1 Score')
    plt.legend()

    # Class F1 grafiği - sınıf 1
    plt.subplot(2, 2, 4)
    train_class_1_f1 = [f1s[1] for f1s in history["train_class_f1s"]]
    plt.plot(epochs, train_class_1_f1, 'b-', label='Training Class 1 F1')
    if has_val:
        val_class_1_f1 = [f1s[1] for f1s in history["val_class_f1s"]]
        plt.plot(epochs, val_class_1_f1, 'r-', label='Validation Class 1 F1')
    plt.title('Class 1 F1 Score')
    plt.xlabel('Epochs')
    plt.ylabel('F1 Score')
    plt.legend()

    plt.tight_layout()
    plt.savefig('tfidf_bilstm_training_history.png')
    plt.show()


# Veriyi yükle
df = pd.read_csv('dataset.csv')
texts = df["text"].values.tolist()
labels = df["label"].values.tolist()

# TF-IDF vektörleştirici
tfidf_vectorizer = TfidfVectorizer(
    max_features=MAX_FEATURES,
    ngram_range=(1, 2),  # Unigram ve bigram
    lowercase=True,
    max_df=0.95,  # Çok yaygın kelimeleri filtrele
    min_df=2      # Çok nadir kelimeleri filtrele
)

# TF-IDF özelliklerini oluştur
tfidf_features = tfidf_vectorizer.fit_transform(texts).toarray()
print(f"TF-IDF özellik boyutu: {tfidf_features.shape}")

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    tfidf_features, labels, test_size=0.2, random_state=42, stratify=labels
)

# Dataset ve DataLoader oluşturma
train_dataset = CustomTFIDFDataset(X_train, y_train)
test_dataset = CustomTFIDFDataset(X_test, y_test)

train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

# Hangi modeli kullanacağımızı seçelim
use_attention = False  # True: Attention mekanizmalı, False: Basit BiLSTM

if use_attention:
    print("BiLSTM + Attention modelini kullanıyoruz...")
    model = TFIDFBiLSTMWithAttention(
        input_size=MAX_FEATURES,
        seq_length=SEQ_LENGTH,
        embedding_dim=EMBEDDING_DIM,
        dropout_rate=DROPOUT_RATE
    ).to(DEVICE)
    model_name = "tfidf_bilstm_attention"
else:
    print("Basit BiLSTM modelini kullanıyoruz...")
    model = TFIDFBiLSTMEnsemble(
        input_size=MAX_FEATURES,
        seq_length=SEQ_LENGTH,
        embedding_dim=EMBEDDING_DIM,
        dropout_rate=DROPOUT_RATE
    ).to(DEVICE)
    model_name = "tfidf_bilstm"

# Sınıf ağırlığı ve Focal Loss parametreleri
class_weights = {0: 1, 1: 6}  # Sınıf dengesizliğine göre
gamma = 2.0  # Focal Loss focusing parametresi

# Modeli eğitme
trained_model, history = train_model(
    model=model,
    train_dataloader=train_dataloader,
    test_dataloader=test_dataloader,
    class_weights=class_weights,
    gamma=gamma,
    num_epochs=100,
    patience=10,
    class_f1_weight=0.6,
    learning_rate=LEARNING_RATE
)

# Eğitim grafiklerini çizdir
plot_training_history(history)

# Son test değerlendirmesi
focal_loss = FocalLoss(
    alpha=torch.tensor([1, 6]).float().to(DEVICE),
    gamma=gamma
)
test_metrics = evaluate_model(trained_model, test_dataloader, focal_loss)

# Sonuçları görüntüleme
print(f"\nTest Metrics:")
print(f"Overall F1 score: {test_metrics['f1_weighted']:.4f}")
print(f"Class 1 F1 score: {test_metrics['f1_by_class'][1]:.4f}")
print(f"Accuracy: {test_metrics['accuracy']:.4f}")
print(f"Confusion Matrix:")
print(test_metrics['confusion_matrix'])

# Model ağırlıklarını kaydet
torch.save(trained_model.state_dict(), f'best_{model_name}.pt')

# TF-IDF vektörleştiriciyi de kaydet
joblib.dump(tfidf_vectorizer, 'tfidf_vectorizer.pkl')

print(f"\nModel ağırlıkları 'best_{model_name}.pt' dosyasına kaydedildi.")
print("TF-IDF vektörleştirici 'tfidf_vectorizer.pkl' dosyasına kaydedildi.")

# Model mimarisini de ayrıca kaydet
# Böylece model yüklenirken doğru mimariye sahip model oluşturulabilir
model_info = {
    'model_type': 'bilstm_attention' if use_attention else 'bilstm',
    'input_size': MAX_FEATURES,
    'seq_length': SEQ_LENGTH,
    'embedding_dim': EMBEDDING_DIM,
    'dropout_rate': DROPOUT_RATE,
    'test_metrics': test_metrics
}
joblib.dump(model_info, f'{model_name}_info.pkl')
print(f"Model bilgileri '{model_name}_info.pkl' dosyasına kaydedildi.")
# Out:
# Kullanılan cihaz: cuda
# TF-IDF özellik boyutu: (35530, 5000)
# Basit BiLSTM modelini kullanıyoruz...
# Epoch 1/100
# Train Loss: 0.7783, Train F1: 0.2765, Train Class 1 F1: 0.2741
# Val Loss: 0.7394, Val F1: 0.0455, Val Class 1 F1: 0.2796
# Epoch 2/100
# Train Loss: 0.6556, Train F1: 0.0532, Train Class 1 F1: 0.2805
# Val Loss: 0.5619, Val F1: 0.0798, Val Class 1 F1: 0.2838
# Validation score improved! Overall F1: 0.0798, Class 1 F1: 0.2838
# Epoch 3/100
# Train Loss: 0.4903, Train F1: 0.2562, Train Class 1 F1: 0.3075
# Val Loss: 0.5109, Val F1: 0.4133, Val Class 1 F1: 0.3320
# Validation score improved! Overall F1: 0.4133, Class 1 F1: 0.3320
# Epoch 4/100
# Train Loss: 0.4250, Train F1: 0.6246, Train Class 1 F1: 0.4120
# Val Loss: 0.5117, Val F1: 0.6689, Val Class 1 F1: 0.4177
# Validation score improved! Overall F1: 0.6689, Class 1 F1: 0.4177
# Epoch 5/100
# Train Loss: 0.3789, Train F1: 0.7925, Train Class 1 F1: 0.5424
# Val Loss: 0.4887, Val F1: 0.8143, Val Class 1 F1: 0.5335
# Validation score improved! Overall F1: 0.8143, Class 1 F1: 0.5335
# Epoch 6/100
# Train Loss: 0.3493, Train F1: 0.8622, Train Class 1 F1: 0.6406
# Val Loss: 0.5050, Val F1: 0.8191, Val Class 1 F1: 0.5373
# Validation score improved! Overall F1: 0.8191, Class 1 F1: 0.5373
# Epoch 7/100
# Train Loss: 0.3318, Train F1: 0.8875, Train Class 1 F1: 0.6893
# Val Loss: 0.5057, Val F1: 0.8418, Val Class 1 F1: 0.5661
# Validation score improved! Overall F1: 0.8418, Class 1 F1: 0.5661
# Epoch 8/100
# Train Loss: 0.3138, Train F1: 0.9039, Train Class 1 F1: 0.7258
# Val Loss: 0.5078, Val F1: 0.8518, Val Class 1 F1: 0.5819
# Validation score improved! Overall F1: 0.8518, Class 1 F1: 0.5819
# Epoch 9/100
# Train Loss: 0.2996, Train F1: 0.9150, Train Class 1 F1: 0.7518
# Val Loss: 0.5062, Val F1: 0.8636, Val Class 1 F1: 0.5999
# Validation score improved! Overall F1: 0.8636, Class 1 F1: 0.5999
# Epoch 10/100
# Train Loss: 0.2909, Train F1: 0.9202, Train Class 1 F1: 0.7650
# Val Loss: 0.5087, Val F1: 0.8669, Val Class 1 F1: 0.6052
# Validation score improved! Overall F1: 0.8669, Class 1 F1: 0.6052
# Epoch 11/100
# Train Loss: 0.2837, Train F1: 0.9257, Train Class 1 F1: 0.7793
# Val Loss: 0.5158, Val F1: 0.8660, Val Class 1 F1: 0.6047
# EarlyStopping counter: 1 out of 10
# Epoch 12/100
# Train Loss: 0.2752, Train F1: 0.9317, Train Class 1 F1: 0.7947
# Val Loss: 0.5110, Val F1: 0.8734, Val Class 1 F1: 0.6173
# Validation score improved! Overall F1: 0.8734, Class 1 F1: 0.6173
# Epoch 13/100
# Train Loss: 0.2703, Train F1: 0.9326, Train Class 1 F1: 0.7974
# Val Loss: 0.5268, Val F1: 0.8577, Val Class 1 F1: 0.5912
# EarlyStopping counter: 1 out of 10
# Epoch 14/100
# Train Loss: 0.2614, Train F1: 0.9362, Train Class 1 F1: 0.8071
# Val Loss: 0.5163, Val F1: 0.8697, Val Class 1 F1: 0.6126
# EarlyStopping counter: 2 out of 10
# Epoch 15/100
# Train Loss: 0.2554, Train F1: 0.9381, Train Class 1 F1: 0.8125
# Val Loss: 0.5206, Val F1: 0.8692, Val Class 1 F1: 0.6117
# EarlyStopping counter: 3 out of 10
# Epoch 16/100
# Train Loss: 0.2474, Train F1: 0.9379, Train Class 1 F1: 0.8128
# Val Loss: 0.5206, Val F1: 0.8737, Val Class 1 F1: 0.6199
# Validation score improved! Overall F1: 0.8737, Class 1 F1: 0.6199
# Epoch 17/100
# Train Loss: 0.2403, Train F1: 0.9377, Train Class 1 F1: 0.8135
# Val Loss: 0.5281, Val F1: 0.8670, Val Class 1 F1: 0.6097
# EarlyStopping counter: 1 out of 10
# Epoch 18/100
# Train Loss: 0.2354, Train F1: 0.9393, Train Class 1 F1: 0.8196
# Val Loss: 0.5203, Val F1: 0.8721, Val Class 1 F1: 0.6184
# EarlyStopping counter: 2 out of 10
# Epoch 19/100
# Train Loss: 0.2258, Train F1: 0.9378, Train Class 1 F1: 0.8175
# Val Loss: 0.5215, Val F1: 0.8634, Val Class 1 F1: 0.6064
# EarlyStopping counter: 3 out of 10
# Epoch 20/100
# Train Loss: 0.2166, Train F1: 0.9351, Train Class 1 F1: 0.8129
# Val Loss: 0.5360, Val F1: 0.8526, Val Class 1 F1: 0.5880
# EarlyStopping counter: 4 out of 10
# Epoch 21/100
# Train Loss: 0.2093, Train F1: 0.9319, Train Class 1 F1: 0.8070
# Val Loss: 0.5387, Val F1: 0.8594, Val Class 1 F1: 0.5978
# EarlyStopping counter: 5 out of 10
# Epoch 22/100
# Train Loss: 0.2044, Train F1: 0.9266, Train Class 1 F1: 0.7953
# Val Loss: 0.5587, Val F1: 0.8402, Val Class 1 F1: 0.5689
# EarlyStopping counter: 6 out of 10
# Epoch 23/100
# Train Loss: 0.1949, Train F1: 0.9251, Train Class 1 F1: 0.7928
# Val Loss: 0.5662, Val F1: 0.8457, Val Class 1 F1: 0.5749
# EarlyStopping counter: 7 out of 10
# Epoch 24/100
# Train Loss: 0.1903, Train F1: 0.9228, Train Class 1 F1: 0.7887
# Val Loss: 0.5781, Val F1: 0.8473, Val Class 1 F1: 0.5788
# EarlyStopping counter: 8 out of 10
# Epoch 25/100
# Train Loss: 0.1900, Train F1: 0.9201, Train Class 1 F1: 0.7826
# Val Loss: 0.5906, Val F1: 0.8328, Val Class 1 F1: 0.5589
# EarlyStopping counter: 9 out of 10
# Epoch 26/100
# Train Loss: 0.1800, Train F1: 0.9205, Train Class 1 F1: 0.7843
# Val Loss: 0.5973, Val F1: 0.8387, Val Class 1 F1: 0.5663
# EarlyStopping counter: 10 out of 10
# Early stopping triggered
# Evaluation Results:
# Accuracy: 0.8718
# F1 Score (Weighted): 0.8737
# F1 Score for Class 1: 0.6199
# Confusion Matrix:
# [[5452, 499], [412, 743]]
#
# Test Metrics:
# Overall F1 score: 0.8737
# Class 1 F1 score: 0.6199
# Accuracy: 0.8718
# Confusion Matrix:
# [[5452, 499], [412, 743]]
#
# Model ağırlıkları 'best_tfidf_bilstm.pt' dosyasına kaydedildi.
# TF-IDF vektörleştirici 'tfidf_vectorizer.pkl' dosyasına kaydedildi.
# Model bilgileri 'tfidf_bilstm_info.pkl' dosyasına kaydedildi.

# %%
import numpy as np
import pandas as pd
import torch
from torch import nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from torch.optim import AdamW
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import f1_score
import copy
import math
import joblib
import pickle
from collections import Counter
import re
from nltk.tokenize import word_tokenize
import nltk
# İlk çalıştırmada gerekli
# nltk.download('punkt')

# Cuda kontrolü
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Kullanılan cihaz: {device}")

# Sabit değerler
BATCH_SIZE = 96
EPOCHS = 5
LEARNING_RATE = 2e-5
DROPOUT_RATE = 0.3
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
MAX_SEQ_LENGTH = 100  # Maksimum sequence uzunluğu
EMBEDDING_DIM = 300   # FastText/Word2Vec embedding boyutu (genelde 300)

class TextPreprocessor:
    def __init__(self, max_seq_length=MAX_SEQ_LENGTH):
        self.max_seq_length = max_seq_length
        self.word_to_idx = {'<UNK>': 0, '<PAD>': 1}
        self.idx_to_word = {0: '<UNK>', 1: '<PAD>'}
        self.vocab_size = 2

    def clean_text(self, text):
        """Metni temizle"""
        text = text.lower()
        text = re.sub(r'[^a-zA-ZğüşıöçĞÜŞIÖÇ\s]', '', text)
        text = re.sub(r'\s+', ' ', text).strip()
        return text

    def tokenize_text(self, text):
        """Metni tokenize et"""
        try:
            tokens = word_tokenize(text)
        except:
            # Eğer nltk tokenizer çalışmazsa basit split kullan
            tokens = text.split()
        return tokens

    def build_vocab_from_texts(self, texts):
        """Metinlerden vocabulary oluştur"""
        word_count = Counter()

        for text in texts:
            cleaned_text = self.clean_text(text)
            tokens = self.tokenize_text(cleaned_text)
            word_count.update(tokens)

        # Sadece 2'den fazla geçen kelimeleri al
        for word, count in word_count.items():
            if count >= 2 and word not in self.word_to_idx:
                self.word_to_idx[word] = self.vocab_size
                self.idx_to_word[self.vocab_size] = word
                self.vocab_size += 1

        print(f"Vocabulary size: {self.vocab_size}")

    def text_to_sequence(self, text):
        """Metni sequence'e çevir"""
        cleaned_text = self.clean_text(text)
        tokens = self.tokenize_text(cleaned_text)

        sequence = []
        for token in tokens:
            if token in self.word_to_idx:
                sequence.append(self.word_to_idx[token])
            else:
                sequence.append(self.word_to_idx['<UNK>'])

        # Padding veya truncation
        if len(sequence) > self.max_seq_length:
            sequence = sequence[:self.max_seq_length]
        else:
            sequence.extend([self.word_to_idx['<PAD>']] * (self.max_seq_length - len(sequence)))

        return sequence

    def texts_to_sequences(self, texts):
        """Birden fazla metni sequence'e çevir"""
        sequences = []
        for text in texts:
            sequence = self.text_to_sequence(text)
            sequences.append(sequence)
        return np.array(sequences)

class EmbeddingLoader:
    def __init__(self, embedding_path, embedding_dim=EMBEDDING_DIM):
        self.embedding_path = embedding_path
        self.embedding_dim = embedding_dim
        self.embeddings = None

    def load_embeddings(self):
        """NPY dosyasından embeddings yükle"""
        print(f"Loading embeddings from {self.embedding_path}")
        self.embeddings = np.load(self.embedding_path)
        print(f"Embeddings shape: {self.embeddings.shape}")
        return self.embeddings

    def create_embedding_matrix(self, word_to_idx, vocab_size):
        """Vocabulary için embedding matrix oluştur"""
        if self.embeddings is None:
            self.load_embeddings()

        # Embedding matrix oluştur
        embedding_matrix = np.random.normal(0, 0.1, (vocab_size, self.embedding_dim))

        # <PAD> token için sıfır vektör
        embedding_matrix[1] = np.zeros(self.embedding_dim)

        # Eğer embeddings kelime bazlı bir dictionary ise (word -> vector)
        # Bu durumda embeddings'i doğrudan kullanabiliriz
        # Ama NPY dosyası sadece vektörler içeriyorsa, kelime-indeks eşleştirmesi yapmalıyız

        # NPY dosyasının formatına göre bu kısmı ayarlamanız gerekebilir
        # Şu an random initialization kullanıyoruz

        return embedding_matrix.astype(np.float32)

class EmbeddingBiLSTM(nn.Module):
    def __init__(self, vocab_size, embedding_dim, embedding_matrix=None,
                 hidden_size=128, num_layers=1, dropout_rate=DROPOUT_RATE,
                 freeze_embeddings=True):
        super(EmbeddingBiLSTM, self).__init__()

        # Embedding layer
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=1)

        # Pre-trained embeddings ile initialize et
        if embedding_matrix is not None:
            self.embedding.weight.data.copy_(torch.from_numpy(embedding_matrix))
            if freeze_embeddings:
                self.embedding.weight.requires_grad = False

        # BiLSTM katmanı
        self.bilstm = nn.LSTM(
            input_size=embedding_dim,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            bidirectional=True,
            dropout=dropout_rate if num_layers > 1 else 0
        )

        # Dropout katmanı
        self.dropout = nn.Dropout(dropout_rate)

        # Sınıflandırıcı katman
        self.classifier = nn.Linear(hidden_size * 2, 2)

    def forward(self, input_ids):
        # Embedding lookup
        embedded = self.embedding(input_ids)  # [batch_size, seq_len, embedding_dim]

        # BiLSTM
        lstm_output, (hidden_state, cell_state) = self.bilstm(embedded)
        # lstm_output: [batch_size, seq_len, 2*hidden_size]

        # Son çıktıyı al
        last_output = lstm_output[:, -1, :]  # [batch_size, 2*hidden_size]

        # Dropout
        last_output = self.dropout(last_output)

        # Sınıflandırma
        logits = self.classifier(last_output)

        return logits

class EmbeddingBiLSTMWithAttention(nn.Module):
    def __init__(self, vocab_size, embedding_dim, embedding_matrix=None,
                 hidden_size=128, num_layers=1, dropout_rate=DROPOUT_RATE,
                 freeze_embeddings=True):
        super(EmbeddingBiLSTMWithAttention, self).__init__()

        self.hidden_size = hidden_size

        # Embedding layer
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx=1)

        # Pre-trained embeddings ile initialize et
        if embedding_matrix is not None:
            self.embedding.weight.data.copy_(torch.from_numpy(embedding_matrix))
            if freeze_embeddings:
                self.embedding.weight.requires_grad = False

        # BiLSTM katmanı
        self.bilstm = nn.LSTM(
            input_size=embedding_dim,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,
            bidirectional=True,
            dropout=dropout_rate if num_layers > 1 else 0
        )

        # Attention mechanism
        self.attention = nn.Linear(hidden_size * 2, 1)

        # Dropout katmanı
        self.dropout = nn.Dropout(dropout_rate)

        # Sınıflandırıcı katman
        self.classifier = nn.Linear(hidden_size * 2, 2)

    def forward(self, input_ids):
        # Embedding lookup
        embedded = self.embedding(input_ids)  # [batch_size, seq_len, embedding_dim]

        # BiLSTM
        lstm_output, (hidden_state, cell_state) = self.bilstm(embedded)
        # lstm_output: [batch_size, seq_len, 2*hidden_size]

        # Attention weights hesapla
        attention_weights = F.softmax(self.attention(lstm_output), dim=1)
        # attention_weights: [batch_size, seq_len, 1]

        # Attention ile ağırlıklı toplam
        attention_output = torch.sum(attention_weights * lstm_output, dim=1)
        # attention_output: [batch_size, 2*hidden_size]

        # Dropout
        attention_output = self.dropout(attention_output)

        # Sınıflandırma
        logits = self.classifier(attention_output)

        return logits

class EmbeddingDataset(Dataset):
    def __init__(self, sequences, labels=None):
        self.sequences = sequences
        self.labels = labels

    def __len__(self):
        return len(self.sequences)

    def __getitem__(self, idx):
        item = {
            'input_ids': torch.tensor(self.sequences[idx], dtype=torch.long)
        }

        if self.labels is not None:
            item['labels'] = torch.tensor(self.labels[idx], dtype=torch.long)

        return item

# Aynı training ve evaluation fonksiyonları (FocalLoss, EarlyStoppingWithClassF1, vs.)
class FocalLoss(nn.Module):
    def __init__(self, alpha=None, gamma=2.0, reduction='mean'):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.reduction = reduction

    def forward(self, inputs, targets):
        log_softmax = nn.functional.log_softmax(inputs, dim=1)
        ce_loss = nn.functional.nll_loss(log_softmax, targets, weight=self.alpha, reduction='none')
        p_t = torch.exp(-ce_loss)
        focal_loss = (1 - p_t) ** self.gamma * ce_loss

        if self.reduction == 'mean':
            return focal_loss.mean()
        elif self.reduction == 'sum':
            return focal_loss.sum()
        else:
            return focal_loss

class EarlyStoppingWithClassF1:
    def __init__(self, patience=5, min_delta=0.001, class_index=1, class_weight=0.5):
        self.patience = patience
        self.min_delta = min_delta
        self.class_index = class_index
        self.class_weight = class_weight
        self.counter = 0
        self.best_score = None
        self.best_class_f1 = None
        self.early_stop = False
        self.best_weights = None

    def __call__(self, model, val_overall_f1, val_class_f1s):
        class_f1 = val_class_f1s[self.class_index]
        combined_score = (1 - self.class_weight) * val_overall_f1 + self.class_weight * class_f1

        if self.best_score is None or self.best_class_f1 is None:
            self.best_score = combined_score
            self.best_class_f1 = class_f1
            self.save_checkpoint(model)
        elif combined_score < self.best_score + self.min_delta:
            self.counter += 1
            print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            class_f1_decrease = self.best_class_f1 - class_f1
            if class_f1_decrease <= self.min_delta:
                print(f'Validation score improved! Overall F1: {val_overall_f1:.4f}, Class 1 F1: {class_f1:.4f}')
                self.best_score = combined_score
                self.best_class_f1 = class_f1
                self.save_checkpoint(model)
                self.counter = 0
            else:
                print(f'Overall score improved but Class 1 F1 dropped too much (from {self.best_class_f1:.4f} to {class_f1:.4f})')
                self.counter += 1
                if self.counter >= self.patience:
                    self.early_stop = True

    def save_checkpoint(self, model):
        self.best_weights = copy.deepcopy(model.state_dict())

    def restore_best_weights(self, model):
        model.load_state_dict(self.best_weights)

def train_model(model, train_dataloader, test_dataloader=None, class_weights=None, gamma=2.0,
                num_epochs=10, patience=3, class_f1_weight=0.6, learning_rate=2e-5):
    device = next(model.parameters()).device

    if class_weights is not None:
        num_classes = len(class_weights)
        alpha = torch.ones(num_classes)
        for cls_idx, weight in class_weights.items():
            alpha[cls_idx] = weight
        alpha = alpha.to(device)
    else:
        alpha = None

    criterion = FocalLoss(alpha=alpha, gamma=gamma)
    optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)
    early_stopping = EarlyStoppingWithClassF1(
        patience=patience,
        class_index=1,
        class_weight=class_f1_weight
    )

    history = {
        'train_loss': [],
        'train_f1': [],
        'train_class_f1s': [],
        'val_loss': [],
        'val_f1': [],
        'val_class_f1s': []
    }

    for epoch in range(num_epochs):
        # Training phase
        model.train()
        train_loss = 0.0
        train_preds = []
        train_labels = []

        for batch in train_dataloader:
            input_ids = batch['input_ids'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids)
            loss = criterion(outputs, labels)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            train_loss += loss.item()

            _, preds = torch.max(outputs, 1)
            train_preds.extend(preds.cpu().numpy())
            train_labels.extend(labels.cpu().numpy())

        train_loss = train_loss / len(train_dataloader)
        train_f1 = f1_score(train_labels, train_preds, average='weighted')
        train_class_f1s = f1_score(train_labels, train_preds, average=None)

        history['train_loss'].append(train_loss)
        history['train_f1'].append(train_f1)
        history['train_class_f1s'].append(train_class_f1s.tolist())

        # Validation phase
        if test_dataloader is not None:
            model.eval()
            val_loss = 0.0
            val_preds = []
            val_labels = []

            with torch.no_grad():
                for batch in test_dataloader:
                    input_ids = batch['input_ids'].to(device)
                    labels = batch['labels'].to(device)

                    outputs = model(input_ids)
                    loss = criterion(outputs, labels)

                    val_loss += loss.item()

                    _, preds = torch.max(outputs, 1)
                    val_preds.extend(preds.cpu().numpy())
                    val_labels.extend(labels.cpu().numpy())

            val_loss = val_loss / len(test_dataloader)
            val_f1 = f1_score(val_labels, val_preds, average='weighted')
            val_class_f1s = f1_score(val_labels, val_preds, average=None)

            history['val_loss'].append(val_loss)
            history['val_f1'].append(val_f1)
            history['val_class_f1s'].append(val_class_f1s.tolist())

            print(f'Epoch {epoch+1}/{num_epochs}')
            print(f'Train Loss: {train_loss:.4f}, Train F1: {train_f1:.4f}, Train Class 1 F1: {train_class_f1s[1]:.4f}')
            print(f'Val Loss: {val_loss:.4f}, Val F1: {val_f1:.4f}, Val Class 1 F1: {val_class_f1s[1]:.4f}')

            early_stopping(model, val_f1, val_class_f1s)

            if early_stopping.early_stop:
                print("Early stopping triggered")
                early_stopping.restore_best_weights(model)
                break
        else:
            print(f'Epoch {epoch+1}/{num_epochs}')
            print(f'Train Loss: {train_loss:.4f}, Train F1: {train_f1:.4f}, Train Class 1 F1: {train_class_f1s[1]:.4f}')

    if test_dataloader is not None and early_stopping.best_weights is not None:
        model.load_state_dict(early_stopping.best_weights)

    return model, history

def evaluate_model(model, dataloader, criterion=None):
    device = next(model.parameters()).device
    model.eval()

    all_preds = []
    all_labels = []
    total_loss = 0.0

    with torch.no_grad():
        for batch in dataloader:
            input_ids = batch['input_ids'].to(device)
            labels = batch['labels'].to(device)

            outputs = model(input_ids)

            if criterion is not None:
                loss = criterion(outputs, labels)
                total_loss += loss.item()

            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, f1_score, precision_score, recall_score

    metrics = {
        'accuracy': accuracy_score(all_labels, all_preds),
        'f1_weighted': f1_score(all_labels, all_preds, average='weighted'),
        'f1_macro': f1_score(all_labels, all_preds, average='macro'),
        'f1_by_class': f1_score(all_labels, all_preds, average=None),
        'precision_weighted': precision_score(all_labels, all_preds, average='weighted'),
        'recall_weighted': recall_score(all_labels, all_preds, average='weighted'),
        'confusion_matrix': confusion_matrix(all_labels, all_preds).tolist(),
        'classification_report': classification_report(all_labels, all_preds, output_dict=True)
    }

    if criterion is not None:
        metrics['loss'] = total_loss / len(dataloader)

    print(f"Evaluation Results:")
    print(f"Accuracy: {metrics['accuracy']:.4f}")
    print(f"F1 Score (Weighted): {metrics['f1_weighted']:.4f}")
    print(f"F1 Score for Class 1: {metrics['f1_by_class'][1]:.4f}")
    print(f"Confusion Matrix:\n{metrics['confusion_matrix']}")

    return metrics

def plot_training_history(history):
    epochs = range(1, len(history["train_loss"]) + 1)
    has_val = "val_loss" in history and len(history["val_loss"]) > 0

    plt.figure(figsize=(16, 12))

    plt.subplot(2, 2, 1)
    plt.plot(epochs, history["train_loss"], 'b-', label='Training Loss')
    if has_val:
        plt.plot(epochs, history["val_loss"], 'r-', label='Validation Loss')
    plt.title('Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.subplot(2, 2, 2)
    plt.plot(epochs, history["train_f1"], 'b-', label='Training F1')
    if has_val:
        plt.plot(epochs, history["val_f1"], 'r-', label='Validation F1')
    plt.title('F1 Score (Weighted)')
    plt.xlabel('Epochs')
    plt.ylabel('F1 Score')
    plt.legend()

    plt.subplot(2, 2, 3)
    train_class_0_f1 = [f1s[0] for f1s in history["train_class_f1s"]]
    plt.plot(epochs, train_class_0_f1, 'b-', label='Training Class 0 F1')
    if has_val:
        val_class_0_f1 = [f1s[0] for f1s in history["val_class_f1s"]]
        plt.plot(epochs, val_class_0_f1, 'r-', label='Validation Class 0 F1')
    plt.title('Class 0 F1 Score')
    plt.xlabel('Epochs')
    plt.ylabel('F1 Score')
    plt.legend()

    plt.subplot(2, 2, 4)
    train_class_1_f1 = [f1s[1] for f1s in history["train_class_f1s"]]
    plt.plot(epochs, train_class_1_f1, 'b-', label='Training Class 1 F1')
    if has_val:
        val_class_1_f1 = [f1s[1] for f1s in history["val_class_f1s"]]
        plt.plot(epochs, val_class_1_f1, 'r-', label='Validation Class 1 F1')
    plt.title('Class 1 F1 Score')
    plt.xlabel('Epochs')
    plt.ylabel('F1 Score')
    plt.legend()

    plt.tight_layout()
    plt.savefig('embedding_bilstm_training_history.png')
    plt.show()


# Veriyi yükle
df = pd.read_csv('dataset.csv')
texts = df["text"].values.tolist()
labels = df["label"].values.tolist()

print(f"Dataset size: {len(texts)}")
print(f"Label distribution: {Counter(labels)}")

# Text preprocessing
preprocessor = TextPreprocessor(max_seq_length=MAX_SEQ_LENGTH)
preprocessor.build_vocab_from_texts(texts)

# Metinleri sequence'lere çevir
sequences = preprocessor.texts_to_sequences(texts)
print(f"Sequences shape: {sequences.shape}")

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(
sequences, labels, test_size=0.2, random_state=42, stratify=labels
)

# FastText ve Word2Vec için ayrı ayrı eğitim
embedding_types = ['fasttext', 'word2vec']
embedding_files = {
'fasttext': 'embedded_fasttext.npy',  # FastText .npy dosyanızın adı
'word2vec': 'embedded_w2v.npy'   # Word2Vec .npy dosyanızın adı
}

for embedding_type in embedding_types:
        print(f"\n{'='*50}")
        print(f"Training with {embedding_type.upper()} embeddings")
        print(f"{'='*50}")

        # Embeddings yükle
        embedding_loader = EmbeddingLoader(embedding_files[embedding_type])
        embedding_matrix = embedding_loader.create_embedding_matrix(
            preprocessor.word_to_idx,
            preprocessor.vocab_size
        )

        # Dataset ve DataLoader oluştur
        train_dataset = EmbeddingDataset(X_train, y_train)
        test_dataset = EmbeddingDataset(X_test, y_test)

        train_dataloader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True)
        test_dataloader = DataLoader(test_dataset, batch_size=BATCH_SIZE)

        # Attention kullanıp kullanmayacağını seç
        use_attention = False  # True: Attention, False: Basit BiLSTM

        if use_attention:
            print(f"Using BiLSTM + Attention with {embedding_type}")
            model = EmbeddingBiLSTMWithAttention(
                vocab_size=preprocessor.vocab_size,
                embedding_dim=EMBEDDING_DIM,
                embedding_matrix=embedding_matrix,
                hidden_size=128,
                dropout_rate=DROPOUT_RATE,
                freeze_embeddings=False  # Embedding'leri fine-tune et
            ).to(DEVICE)
            model_name = f"{embedding_type}_bilstm_attention"
        else:
            print(f"Using BiLSTM with {embedding_type}")
            model = EmbeddingBiLSTM(
                vocab_size=preprocessor.vocab_size,
                embedding_dim=EMBEDDING_DIM,
                embedding_matrix=embedding_matrix,
                hidden_size=128,
                dropout_rate=DROPOUT_RATE,
                freeze_embeddings=False
            ).to(DEVICE)
            model_name = f"{embedding_type}_bilstm"

        # Model parametrelerini göster
        total_params = sum(p.numel() for p in model.parameters())
        trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
        print(f"Total parameters: {total_params:,}")
        print(f"Trainable parameters: {trainable_params:,}")

        # Sınıf ağırlığı
        class_weights = {0: 1, 1: 6}
        gamma = 2.0

        # Modeli eğit
        trained_model, history = train_model(
            model=model,
            train_dataloader=train_dataloader,
            test_dataloader=test_dataloader,
            class_weights=class_weights,
            gamma=gamma,
            num_epochs=100,
            patience=10,
            class_f1_weight=0.6,
            learning_rate=LEARNING_RATE
        )

        # Training history çiz
        plot_training_history(history)

        # Final evaluation
        focal_loss = FocalLoss(
            alpha=torch.tensor([1, 6]).float().to(DEVICE),
            gamma=gamma
        )
        test_metrics = evaluate_model(trained_model, test_dataloader, focal_loss)

        print(f"\n{embedding_type.upper()} Test Results:")
        print(f"Overall F1 score: {test_metrics['f1_weighted']:.4f}")
        print(f"Class 1 F1 score: {test_metrics['f1_by_class'][1]:.4f}")
        print(f"Accuracy: {test_metrics['accuracy']:.4f}")

        # Model kaydet
        torch.save(trained_model.state_dict(), f'best_{model_name}.pt')

        # Model bilgilerini kaydet
        model_info = {
            'embedding_type': embedding_type,
            'model_type': 'bilstm_attention' if use_attention else 'bilstm',
            'vocab_size': preprocessor.vocab_size,
            'embedding_dim': EMBEDDING_DIM,
            'max_seq_length': MAX_SEQ_LENGTH,
            'dropout_rate': DROPOUT_RATE,
            'test_metrics': test_metrics,
            'word_to_idx': preprocessor.word_to_idx
        }
        joblib.dump(model_info, f'{model_name}_info.pkl')

        print(f"Model saved as 'best_{model_name}.pt'")
        print(f"Model info saved as '{model_name}_info.pkl'")
# Out:
# Kullanılan cihaz: cuda
# Dataset size: 35530
# Label distribution: Counter({0: 29755, 1: 5775})
# Vocabulary size: 60179
# Sequences shape: (35530, 100)
#
# ==================================================
# Training with FASTTEXT embeddings
# ==================================================
# Loading embeddings from embedded_fasttext.npy
# Embeddings shape: (35225, 100)
# Using BiLSTM with fasttext
# Total parameters: 18,494,534
# Trainable parameters: 18,494,534
# Epoch 1/100
# Train Loss: 0.7667, Train F1: 0.0456, Train Class 1 F1: 0.2796
# Val Loss: 0.7398, Val F1: 0.0455, Val Class 1 F1: 0.2796
# Epoch 2/100
# Train Loss: 0.7312, Train F1: 0.0455, Train Class 1 F1: 0.2796
# Val Loss: 0.7205, Val F1: 0.0455, Val Class 1 F1: 0.2796
# EarlyStopping counter: 1 out of 10
# Epoch 3/100
# Train Loss: 0.7240, Train F1: 0.0455, Train Class 1 F1: 0.2796
# Val Loss: 0.7197, Val F1: 0.0455, Val Class 1 F1: 0.2796
# EarlyStopping counter: 2 out of 10
# Epoch 4/100
# Train Loss: 0.7233, Train F1: 0.0455, Train Class 1 F1: 0.2796
# Val Loss: 0.7187, Val F1: 0.0455, Val Class 1 F1: 0.2796
# EarlyStopping counter: 3 out of 10
# Epoch 5/100
# Train Loss: 0.7220, Train F1: 0.0455, Train Class 1 F1: 0.2796
# Val Loss: 0.7180, Val F1: 0.0455, Val Class 1 F1: 0.2796
# EarlyStopping counter: 4 out of 10
# Epoch 6/100
# Train Loss: 0.7194, Train F1: 0.0455, Train Class 1 F1: 0.2796
# Val Loss: 0.7171, Val F1: 0.0455, Val Class 1 F1: 0.2796
# EarlyStopping counter: 5 out of 10
# Epoch 7/100
# Train Loss: 0.7175, Train F1: 0.0455, Train Class 1 F1: 0.2796
# Val Loss: 0.7160, Val F1: 0.0455, Val Class 1 F1: 0.2796
# EarlyStopping counter: 6 out of 10
# Epoch 8/100
# Train Loss: 0.7179, Train F1: 0.0459, Train Class 1 F1: 0.2797
# Val Loss: 0.7149, Val F1: 0.0457, Val Class 1 F1: 0.2797
# EarlyStopping counter: 7 out of 10
# Epoch 9/100
# Train Loss: 0.7154, Train F1: 0.0470, Train Class 1 F1: 0.2798
# Val Loss: 0.7146, Val F1: 0.0472, Val Class 1 F1: 0.2798
# EarlyStopping counter: 8 out of 10
# Epoch 10/100
# Train Loss: 0.7154, Train F1: 0.0510, Train Class 1 F1: 0.2802
# Val Loss: 0.7133, Val F1: 0.0522, Val Class 1 F1: 0.2800
# Validation score improved! Overall F1: 0.0522, Class 1 F1: 0.2800
# Epoch 11/100
# Train Loss: 0.7156, Train F1: 0.0598, Train Class 1 F1: 0.2810
# Val Loss: 0.7125, Val F1: 0.0609, Val Class 1 F1: 0.2805
# Validation score improved! Overall F1: 0.0609, Class 1 F1: 0.2805
# Epoch 12/100
# Train Loss: 0.7110, Train F1: 0.0745, Train Class 1 F1: 0.2829
# Val Loss: 0.7116, Val F1: 0.0725, Val Class 1 F1: 0.2808
# Validation score improved! Overall F1: 0.0725, Class 1 F1: 0.2808
# Epoch 13/100
# Train Loss: 0.7087, Train F1: 0.0978, Train Class 1 F1: 0.2856
# Val Loss: 0.7094, Val F1: 0.0915, Val Class 1 F1: 0.2822
# Validation score improved! Overall F1: 0.0915, Class 1 F1: 0.2822
# Epoch 14/100
# Train Loss: 0.6950, Train F1: 0.1307, Train Class 1 F1: 0.2899
# Val Loss: 0.6766, Val F1: 0.1297, Val Class 1 F1: 0.2852
# Validation score improved! Overall F1: 0.1297, Class 1 F1: 0.2852
# Epoch 15/100
# Train Loss: 0.6200, Train F1: 0.1618, Train Class 1 F1: 0.2947
# Val Loss: 0.6269, Val F1: 0.1650, Val Class 1 F1: 0.2895
# Validation score improved! Overall F1: 0.1650, Class 1 F1: 0.2895
# Epoch 16/100
# Train Loss: 0.5568, Train F1: 0.2218, Train Class 1 F1: 0.3038
# Val Loss: 0.6215, Val F1: 0.2266, Val Class 1 F1: 0.2947
# Validation score improved! Overall F1: 0.2266, Class 1 F1: 0.2947
# Epoch 17/100
# Train Loss: 0.5103, Train F1: 0.2833, Train Class 1 F1: 0.3134
# Val Loss: 0.5669, Val F1: 0.2921, Val Class 1 F1: 0.3004
# Validation score improved! Overall F1: 0.2921, Class 1 F1: 0.3004
# Epoch 18/100
# Train Loss: 0.4765, Train F1: 0.3693, Train Class 1 F1: 0.3278
# Val Loss: 0.5570, Val F1: 0.3782, Val Class 1 F1: 0.3111
# Validation score improved! Overall F1: 0.3782, Class 1 F1: 0.3111
# Epoch 19/100
# Train Loss: 0.4492, Train F1: 0.4816, Train Class 1 F1: 0.3516
# Val Loss: 0.5503, Val F1: 0.5590, Val Class 1 F1: 0.3476
# Validation score improved! Overall F1: 0.5590, Class 1 F1: 0.3476
# Epoch 20/100
# Train Loss: 0.4263, Train F1: 0.6343, Train Class 1 F1: 0.4085
# Val Loss: 0.5425, Val F1: 0.7680, Val Class 1 F1: 0.4608
# Validation score improved! Overall F1: 0.7680, Class 1 F1: 0.4608
# Epoch 21/100
# Train Loss: 0.4043, Train F1: 0.7876, Train Class 1 F1: 0.5299
# Val Loss: 0.5465, Val F1: 0.8589, Val Class 1 F1: 0.5687
# Validation score improved! Overall F1: 0.8589, Class 1 F1: 0.5687
# Epoch 22/100
# Train Loss: 0.3829, Train F1: 0.8624, Train Class 1 F1: 0.6370
# Val Loss: 0.5392, Val F1: 0.7683, Val Class 1 F1: 0.4656
# EarlyStopping counter: 1 out of 10
# Epoch 23/100
# Train Loss: 0.3629, Train F1: 0.8894, Train Class 1 F1: 0.6915
# Val Loss: 0.5290, Val F1: 0.8398, Val Class 1 F1: 0.5520
# EarlyStopping counter: 2 out of 10
# Epoch 24/100
# Train Loss: 0.3514, Train F1: 0.8986, Train Class 1 F1: 0.7111
# Val Loss: 0.5250, Val F1: 0.8576, Val Class 1 F1: 0.5831
# Validation score improved! Overall F1: 0.8576, Class 1 F1: 0.5831
# Epoch 25/100
# Train Loss: 0.3356, Train F1: 0.9098, Train Class 1 F1: 0.7385
# Val Loss: 0.5318, Val F1: 0.8299, Val Class 1 F1: 0.5441
# EarlyStopping counter: 1 out of 10
# Epoch 26/100
# Train Loss: 0.3238, Train F1: 0.9181, Train Class 1 F1: 0.7594
# Val Loss: 0.5280, Val F1: 0.8683, Val Class 1 F1: 0.5992
# Validation score improved! Overall F1: 0.8683, Class 1 F1: 0.5992
# Epoch 27/100
# Train Loss: 0.3074, Train F1: 0.9260, Train Class 1 F1: 0.7804
# Val Loss: 0.5293, Val F1: 0.8472, Val Class 1 F1: 0.5707
# EarlyStopping counter: 1 out of 10
# Epoch 28/100
# Train Loss: 0.2970, Train F1: 0.9312, Train Class 1 F1: 0.7945
# Val Loss: 0.5308, Val F1: 0.8658, Val Class 1 F1: 0.5990
# EarlyStopping counter: 2 out of 10
# Epoch 29/100
# Train Loss: 0.2893, Train F1: 0.9341, Train Class 1 F1: 0.8024
# Val Loss: 0.5313, Val F1: 0.8659, Val Class 1 F1: 0.6011
# EarlyStopping counter: 3 out of 10
# Epoch 30/100
# Train Loss: 0.2792, Train F1: 0.9370, Train Class 1 F1: 0.8113
# Val Loss: 0.5340, Val F1: 0.8738, Val Class 1 F1: 0.6163
# Validation score improved! Overall F1: 0.8738, Class 1 F1: 0.6163
# Epoch 31/100
# Train Loss: 0.2716, Train F1: 0.9402, Train Class 1 F1: 0.8204
# Val Loss: 0.5418, Val F1: 0.8758, Val Class 1 F1: 0.6161
# EarlyStopping counter: 1 out of 10
# Epoch 32/100
# Train Loss: 0.2631, Train F1: 0.9413, Train Class 1 F1: 0.8240
# Val Loss: 0.5350, Val F1: 0.8693, Val Class 1 F1: 0.6105
# EarlyStopping counter: 2 out of 10
# Epoch 33/100
# Train Loss: 0.2606, Train F1: 0.9432, Train Class 1 F1: 0.8294
# Val Loss: 0.5372, Val F1: 0.8711, Val Class 1 F1: 0.6146
# EarlyStopping counter: 3 out of 10
# Epoch 34/100
# Train Loss: 0.2527, Train F1: 0.9455, Train Class 1 F1: 0.8362
# Val Loss: 0.5355, Val F1: 0.8765, Val Class 1 F1: 0.6248
# Validation score improved! Overall F1: 0.8765, Class 1 F1: 0.6248
# Epoch 35/100
# Train Loss: 0.2445, Train F1: 0.9458, Train Class 1 F1: 0.8376
# Val Loss: 0.5423, Val F1: 0.8762, Val Class 1 F1: 0.6223
# EarlyStopping counter: 1 out of 10
# Epoch 36/100
# Train Loss: 0.2388, Train F1: 0.9478, Train Class 1 F1: 0.8434
# Val Loss: 0.5406, Val F1: 0.8794, Val Class 1 F1: 0.6288
# Validation score improved! Overall F1: 0.8794, Class 1 F1: 0.6288
# Epoch 37/100
# Train Loss: 0.2382, Train F1: 0.9443, Train Class 1 F1: 0.8345
# Val Loss: 0.5515, Val F1: 0.8739, Val Class 1 F1: 0.6194
# EarlyStopping counter: 1 out of 10
# Epoch 38/100
# Train Loss: 0.2283, Train F1: 0.9519, Train Class 1 F1: 0.8551
# Val Loss: 0.5520, Val F1: 0.8718, Val Class 1 F1: 0.6168
# EarlyStopping counter: 2 out of 10
# Epoch 39/100
# Train Loss: 0.2263, Train F1: 0.9523, Train Class 1 F1: 0.8565
# Val Loss: 0.5502, Val F1: 0.8740, Val Class 1 F1: 0.6197
# EarlyStopping counter: 3 out of 10
# Epoch 40/100
# Train Loss: 0.2174, Train F1: 0.9538, Train Class 1 F1: 0.8611
# Val Loss: 0.5481, Val F1: 0.8696, Val Class 1 F1: 0.6151
# EarlyStopping counter: 4 out of 10
# Epoch 41/100
# Train Loss: 0.2122, Train F1: 0.9541, Train Class 1 F1: 0.8626
# Val Loss: 0.5513, Val F1: 0.8602, Val Class 1 F1: 0.6032
# EarlyStopping counter: 5 out of 10
# Epoch 42/100
# Train Loss: 0.2060, Train F1: 0.9551, Train Class 1 F1: 0.8657
# Val Loss: 0.5509, Val F1: 0.8779, Val Class 1 F1: 0.6291
# EarlyStopping counter: 6 out of 10
# Epoch 43/100
# Train Loss: 0.2010, Train F1: 0.9564, Train Class 1 F1: 0.8694
# Val Loss: 0.5590, Val F1: 0.8819, Val Class 1 F1: 0.6350
# Validation score improved! Overall F1: 0.8819, Class 1 F1: 0.6350
# Epoch 44/100
# Train Loss: 0.1968, Train F1: 0.9567, Train Class 1 F1: 0.8705
# Val Loss: 0.5493, Val F1: 0.8759, Val Class 1 F1: 0.6283
# EarlyStopping counter: 1 out of 10
# Epoch 45/100
# Train Loss: 0.1926, Train F1: 0.9557, Train Class 1 F1: 0.8684
# Val Loss: 0.5571, Val F1: 0.8717, Val Class 1 F1: 0.6200
# EarlyStopping counter: 2 out of 10
# Epoch 46/100
# Train Loss: 0.1866, Train F1: 0.9587, Train Class 1 F1: 0.8766
# Val Loss: 0.5579, Val F1: 0.8731, Val Class 1 F1: 0.6234
# EarlyStopping counter: 3 out of 10
# Epoch 47/100
# Train Loss: 0.1927, Train F1: 0.9560, Train Class 1 F1: 0.8689
# Val Loss: 0.5551, Val F1: 0.8687, Val Class 1 F1: 0.6151
# EarlyStopping counter: 4 out of 10
# Epoch 48/100
# Train Loss: 0.1824, Train F1: 0.9595, Train Class 1 F1: 0.8792
# Val Loss: 0.5576, Val F1: 0.8809, Val Class 1 F1: 0.6387
# Validation score improved! Overall F1: 0.8809, Class 1 F1: 0.6387
# Epoch 49/100
# Train Loss: 0.1741, Train F1: 0.9594, Train Class 1 F1: 0.8792
# Val Loss: 0.5700, Val F1: 0.8673, Val Class 1 F1: 0.6112
# EarlyStopping counter: 1 out of 10
# Epoch 50/100
# Train Loss: 0.1884, Train F1: 0.9553, Train Class 1 F1: 0.8673
# Val Loss: 0.5624, Val F1: 0.8700, Val Class 1 F1: 0.6182
# EarlyStopping counter: 2 out of 10
# Epoch 51/100
# Train Loss: 0.1622, Train F1: 0.9621, Train Class 1 F1: 0.8873
# Val Loss: 0.5688, Val F1: 0.8806, Val Class 1 F1: 0.6373
# EarlyStopping counter: 3 out of 10
# Epoch 52/100
# Train Loss: 0.1597, Train F1: 0.9613, Train Class 1 F1: 0.8853
# Val Loss: 0.5775, Val F1: 0.8759, Val Class 1 F1: 0.6283
# EarlyStopping counter: 4 out of 10
# Epoch 53/100
# Train Loss: 0.1538, Train F1: 0.9642, Train Class 1 F1: 0.8934
# Val Loss: 0.5856, Val F1: 0.8800, Val Class 1 F1: 0.6336
# EarlyStopping counter: 5 out of 10
# Epoch 54/100
# Train Loss: 0.1474, Train F1: 0.9646, Train Class 1 F1: 0.8949
# Val Loss: 0.5928, Val F1: 0.8779, Val Class 1 F1: 0.6298
# EarlyStopping counter: 6 out of 10
# Epoch 55/100
# Train Loss: 0.1471, Train F1: 0.9643, Train Class 1 F1: 0.8940
# Val Loss: 0.5996, Val F1: 0.8737, Val Class 1 F1: 0.6233
# EarlyStopping counter: 7 out of 10
# Epoch 56/100
# Train Loss: 0.1425, Train F1: 0.9655, Train Class 1 F1: 0.8977
# Val Loss: 0.6217, Val F1: 0.8854, Val Class 1 F1: 0.6414
# Validation score improved! Overall F1: 0.8854, Class 1 F1: 0.6414
# Epoch 57/100
# Train Loss: 0.1431, Train F1: 0.9640, Train Class 1 F1: 0.8935
# Val Loss: 0.6178, Val F1: 0.8840, Val Class 1 F1: 0.6407
# EarlyStopping counter: 1 out of 10
# Epoch 58/100
# Train Loss: 0.1366, Train F1: 0.9672, Train Class 1 F1: 0.9027
# Val Loss: 0.6175, Val F1: 0.8822, Val Class 1 F1: 0.6368
# EarlyStopping counter: 2 out of 10
# Epoch 59/100
# Train Loss: 0.1365, Train F1: 0.9658, Train Class 1 F1: 0.8988
# Val Loss: 0.6167, Val F1: 0.8769, Val Class 1 F1: 0.6287
# EarlyStopping counter: 3 out of 10
# Epoch 60/100
# Train Loss: 0.1310, Train F1: 0.9687, Train Class 1 F1: 0.9070
# Val Loss: 0.6240, Val F1: 0.8801, Val Class 1 F1: 0.6336
# EarlyStopping counter: 4 out of 10
# Epoch 61/100
# Train Loss: 0.1277, Train F1: 0.9694, Train Class 1 F1: 0.9087
# Val Loss: 0.6417, Val F1: 0.8850, Val Class 1 F1: 0.6392
# EarlyStopping counter: 5 out of 10
# Epoch 62/100
# Train Loss: 0.1297, Train F1: 0.9668, Train Class 1 F1: 0.9018
# Val Loss: 0.6413, Val F1: 0.8807, Val Class 1 F1: 0.6329
# EarlyStopping counter: 6 out of 10
# Epoch 63/100
# Train Loss: 0.1252, Train F1: 0.9693, Train Class 1 F1: 0.9086
# Val Loss: 0.6252, Val F1: 0.8789, Val Class 1 F1: 0.6309
# EarlyStopping counter: 7 out of 10
# Epoch 64/100
# Train Loss: 0.1226, Train F1: 0.9673, Train Class 1 F1: 0.9033
# Val Loss: 0.6375, Val F1: 0.8800, Val Class 1 F1: 0.6323
# EarlyStopping counter: 8 out of 10
# Epoch 65/100
# Train Loss: 0.1177, Train F1: 0.9702, Train Class 1 F1: 0.9115
# Val Loss: 0.6454, Val F1: 0.8823, Val Class 1 F1: 0.6368
# EarlyStopping counter: 9 out of 10
# Epoch 66/100
# Train Loss: 0.1172, Train F1: 0.9694, Train Class 1 F1: 0.9092
# Val Loss: 0.6558, Val F1: 0.8826, Val Class 1 F1: 0.6353
# EarlyStopping counter: 10 out of 10
# Early stopping triggered
# Evaluation Results:
# Accuracy: 0.8867
# F1 Score (Weighted): 0.8854
# F1 Score for Class 1: 0.6414
# Confusion Matrix:
# [[5581, 370], [435, 720]]
#
# FASTTEXT Test Results:
# Overall F1 score: 0.8854
# Class 1 F1 score: 0.6414
# Accuracy: 0.8867
# Model saved as 'best_fasttext_bilstm.pt'
# Model info saved as 'fasttext_bilstm_info.pkl'
#
# ==================================================
# Training with WORD2VEC embeddings
# ==================================================
# Loading embeddings from embedded_w2v.npy
# Embeddings shape: (35225, 100)
# Using BiLSTM with word2vec
# Total parameters: 18,494,534
# Trainable parameters: 18,494,534
# Epoch 1/100
# Train Loss: 0.7808, Train F1: 0.2373, Train Class 1 F1: 0.2717
# Val Loss: 0.7514, Val F1: 0.0455, Val Class 1 F1: 0.2796
# Epoch 2/100
# Train Loss: 0.7363, Train F1: 0.0455, Train Class 1 F1: 0.2796
# Val Loss: 0.7205, Val F1: 0.0455, Val Class 1 F1: 0.2796
# EarlyStopping counter: 1 out of 10
# Epoch 3/100
# Train Loss: 0.7259, Train F1: 0.0455, Train Class 1 F1: 0.2796
# Val Loss: 0.7191, Val F1: 0.0455, Val Class 1 F1: 0.2796
# EarlyStopping counter: 2 out of 10
# Epoch 4/100
# Train Loss: 0.7225, Train F1: 0.0455, Train Class 1 F1: 0.2796
# Val Loss: 0.7181, Val F1: 0.0455, Val Class 1 F1: 0.2796
# EarlyStopping counter: 3 out of 10
# Epoch 5/100
# Train Loss: 0.7213, Train F1: 0.0455, Train Class 1 F1: 0.2796
# Val Loss: 0.7168, Val F1: 0.0455, Val Class 1 F1: 0.2796
# EarlyStopping counter: 4 out of 10
# Epoch 6/100
# Train Loss: 0.7200, Train F1: 0.0455, Train Class 1 F1: 0.2796
# Val Loss: 0.7157, Val F1: 0.0455, Val Class 1 F1: 0.2796
# EarlyStopping counter: 5 out of 10
# Epoch 7/100
# Train Loss: 0.7181, Train F1: 0.0455, Train Class 1 F1: 0.2796
# Val Loss: 0.7146, Val F1: 0.0455, Val Class 1 F1: 0.2796
# EarlyStopping counter: 6 out of 10
# Epoch 8/100
# Train Loss: 0.7153, Train F1: 0.0458, Train Class 1 F1: 0.2797
# Val Loss: 0.7137, Val F1: 0.0460, Val Class 1 F1: 0.2795
# EarlyStopping counter: 7 out of 10
# Epoch 9/100
# Train Loss: 0.7159, Train F1: 0.0483, Train Class 1 F1: 0.2799
# Val Loss: 0.7129, Val F1: 0.0508, Val Class 1 F1: 0.2799
# Validation score improved! Overall F1: 0.0508, Class 1 F1: 0.2799
# Epoch 10/100
# Train Loss: 0.7132, Train F1: 0.0556, Train Class 1 F1: 0.2807
# Val Loss: 0.7121, Val F1: 0.0607, Val Class 1 F1: 0.2806
# Validation score improved! Overall F1: 0.0607, Class 1 F1: 0.2806
# Epoch 11/100
# Train Loss: 0.7119, Train F1: 0.0737, Train Class 1 F1: 0.2826
# Val Loss: 0.7112, Val F1: 0.0759, Val Class 1 F1: 0.2821
# Validation score improved! Overall F1: 0.0759, Class 1 F1: 0.2821
# Epoch 12/100
# Train Loss: 0.7110, Train F1: 0.0986, Train Class 1 F1: 0.2857
# Val Loss: 0.7137, Val F1: 0.0927, Val Class 1 F1: 0.2830
# Validation score improved! Overall F1: 0.0927, Class 1 F1: 0.2830
# Epoch 13/100
# Train Loss: 0.7058, Train F1: 0.1257, Train Class 1 F1: 0.2893
# Val Loss: 0.7068, Val F1: 0.1281, Val Class 1 F1: 0.2856
# Validation score improved! Overall F1: 0.1281, Class 1 F1: 0.2856
# Epoch 14/100
# Train Loss: 0.6602, Train F1: 0.1715, Train Class 1 F1: 0.2958
# Val Loss: 0.6329, Val F1: 0.1519, Val Class 1 F1: 0.2882
# Validation score improved! Overall F1: 0.1519, Class 1 F1: 0.2882
# Epoch 15/100
# Train Loss: 0.5599, Train F1: 0.2150, Train Class 1 F1: 0.3028
# Val Loss: 0.5873, Val F1: 0.2212, Val Class 1 F1: 0.2933
# Validation score improved! Overall F1: 0.2212, Class 1 F1: 0.2933
# Epoch 16/100
# Train Loss: 0.5136, Train F1: 0.2811, Train Class 1 F1: 0.3138
# Val Loss: 0.5688, Val F1: 0.2980, Val Class 1 F1: 0.3016
# Validation score improved! Overall F1: 0.2980, Class 1 F1: 0.3016
# Epoch 17/100
# Train Loss: 0.4726, Train F1: 0.3887, Train Class 1 F1: 0.3325
# Val Loss: 0.5604, Val F1: 0.3757, Val Class 1 F1: 0.3119
# Validation score improved! Overall F1: 0.3757, Class 1 F1: 0.3119
# Epoch 18/100
# Train Loss: 0.4463, Train F1: 0.5696, Train Class 1 F1: 0.3808
# Val Loss: 0.5487, Val F1: 0.5688, Val Class 1 F1: 0.3565
# Validation score improved! Overall F1: 0.5688, Class 1 F1: 0.3565
# Epoch 19/100
# Train Loss: 0.4239, Train F1: 0.7269, Train Class 1 F1: 0.4696
# Val Loss: 0.5524, Val F1: 0.5835, Val Class 1 F1: 0.3602
# Validation score improved! Overall F1: 0.5835, Class 1 F1: 0.3602
# Epoch 20/100
# Train Loss: 0.4061, Train F1: 0.8220, Train Class 1 F1: 0.5731
# Val Loss: 0.5427, Val F1: 0.7770, Val Class 1 F1: 0.4692
# Validation score improved! Overall F1: 0.7770, Class 1 F1: 0.4692
# Epoch 21/100
# Train Loss: 0.3905, Train F1: 0.8663, Train Class 1 F1: 0.6432
# Val Loss: 0.5486, Val F1: 0.7931, Val Class 1 F1: 0.4910
# Validation score improved! Overall F1: 0.7931, Class 1 F1: 0.4910
# Epoch 22/100
# Train Loss: 0.4009, Train F1: 0.8893, Train Class 1 F1: 0.6815
# Val Loss: 0.5747, Val F1: 0.8619, Val Class 1 F1: 0.5574
# Validation score improved! Overall F1: 0.8619, Class 1 F1: 0.5574
# Epoch 23/100
# Train Loss: 0.3616, Train F1: 0.8954, Train Class 1 F1: 0.7049
# Val Loss: 0.5362, Val F1: 0.8547, Val Class 1 F1: 0.5682
# Validation score improved! Overall F1: 0.8547, Class 1 F1: 0.5682
# Epoch 24/100
# Train Loss: 0.3502, Train F1: 0.9060, Train Class 1 F1: 0.7294
# Val Loss: 0.5363, Val F1: 0.8492, Val Class 1 F1: 0.5615
# EarlyStopping counter: 1 out of 10
# Epoch 25/100
# Train Loss: 0.3369, Train F1: 0.9142, Train Class 1 F1: 0.7490
# Val Loss: 0.5387, Val F1: 0.8496, Val Class 1 F1: 0.5634
# EarlyStopping counter: 2 out of 10
# Epoch 26/100
# Train Loss: 0.3292, Train F1: 0.9181, Train Class 1 F1: 0.7600
# Val Loss: 0.5394, Val F1: 0.8454, Val Class 1 F1: 0.5638
# EarlyStopping counter: 3 out of 10
# Epoch 27/100
# Train Loss: 0.3202, Train F1: 0.9203, Train Class 1 F1: 0.7667
# Val Loss: 0.5405, Val F1: 0.8594, Val Class 1 F1: 0.5837
# Validation score improved! Overall F1: 0.8594, Class 1 F1: 0.5837
# Epoch 28/100
# Train Loss: 0.3069, Train F1: 0.9241, Train Class 1 F1: 0.7774
# Val Loss: 0.5398, Val F1: 0.8424, Val Class 1 F1: 0.5617
# EarlyStopping counter: 1 out of 10
# Epoch 29/100
# Train Loss: 0.2928, Train F1: 0.9292, Train Class 1 F1: 0.7910
# Val Loss: 0.5418, Val F1: 0.8474, Val Class 1 F1: 0.5692
# EarlyStopping counter: 2 out of 10
# Epoch 30/100
# Train Loss: 0.2854, Train F1: 0.9321, Train Class 1 F1: 0.7991
# Val Loss: 0.5392, Val F1: 0.8501, Val Class 1 F1: 0.5770
# EarlyStopping counter: 3 out of 10
# Epoch 31/100
# Train Loss: 0.2770, Train F1: 0.9351, Train Class 1 F1: 0.8079
# Val Loss: 0.5488, Val F1: 0.8658, Val Class 1 F1: 0.5974
# Validation score improved! Overall F1: 0.8658, Class 1 F1: 0.5974
# Epoch 32/100
# Train Loss: 0.2676, Train F1: 0.9383, Train Class 1 F1: 0.8166
# Val Loss: 0.5386, Val F1: 0.8539, Val Class 1 F1: 0.5850
# EarlyStopping counter: 1 out of 10
# Epoch 33/100
# Train Loss: 0.2605, Train F1: 0.9391, Train Class 1 F1: 0.8195
# Val Loss: 0.5430, Val F1: 0.8558, Val Class 1 F1: 0.5879
# EarlyStopping counter: 2 out of 10
# Epoch 34/100
# Train Loss: 0.2518, Train F1: 0.9412, Train Class 1 F1: 0.8259
# Val Loss: 0.5475, Val F1: 0.8692, Val Class 1 F1: 0.6088
# Validation score improved! Overall F1: 0.8692, Class 1 F1: 0.6088
# Epoch 35/100
# Train Loss: 0.2470, Train F1: 0.9452, Train Class 1 F1: 0.8368
# Val Loss: 0.5445, Val F1: 0.8578, Val Class 1 F1: 0.5925
# EarlyStopping counter: 1 out of 10
# Epoch 36/100
# Train Loss: 0.2399, Train F1: 0.9433, Train Class 1 F1: 0.8323
# Val Loss: 0.5472, Val F1: 0.8702, Val Class 1 F1: 0.6115
# Validation score improved! Overall F1: 0.8702, Class 1 F1: 0.6115
# Epoch 37/100
# Train Loss: 0.2349, Train F1: 0.9445, Train Class 1 F1: 0.8356
# Val Loss: 0.5446, Val F1: 0.8650, Val Class 1 F1: 0.6049
# EarlyStopping counter: 1 out of 10
# Epoch 38/100
# Train Loss: 0.2273, Train F1: 0.9470, Train Class 1 F1: 0.8430
# Val Loss: 0.5527, Val F1: 0.8741, Val Class 1 F1: 0.6189
# Validation score improved! Overall F1: 0.8741, Class 1 F1: 0.6189
# Epoch 39/100
# Train Loss: 0.2202, Train F1: 0.9484, Train Class 1 F1: 0.8473
# Val Loss: 0.5488, Val F1: 0.8693, Val Class 1 F1: 0.6136
# EarlyStopping counter: 1 out of 10
# Epoch 40/100
# Train Loss: 0.2133, Train F1: 0.9510, Train Class 1 F1: 0.8544
# Val Loss: 0.5550, Val F1: 0.8569, Val Class 1 F1: 0.5916
# EarlyStopping counter: 2 out of 10
# Epoch 41/100
# Train Loss: 0.2092, Train F1: 0.9494, Train Class 1 F1: 0.8506
# Val Loss: 0.5559, Val F1: 0.8711, Val Class 1 F1: 0.6188
# EarlyStopping counter: 3 out of 10
# Epoch 42/100
# Train Loss: 0.2057, Train F1: 0.9496, Train Class 1 F1: 0.8515
# Val Loss: 0.5530, Val F1: 0.8660, Val Class 1 F1: 0.6089
# EarlyStopping counter: 4 out of 10
# Epoch 43/100
# Train Loss: 0.1998, Train F1: 0.9529, Train Class 1 F1: 0.8606
# Val Loss: 0.5599, Val F1: 0.8734, Val Class 1 F1: 0.6201
# EarlyStopping counter: 5 out of 10
# Epoch 44/100
# Train Loss: 0.1949, Train F1: 0.9535, Train Class 1 F1: 0.8626
# Val Loss: 0.5635, Val F1: 0.8738, Val Class 1 F1: 0.6229
# Validation score improved! Overall F1: 0.8738, Class 1 F1: 0.6229
# Epoch 45/100
# Train Loss: 0.1852, Train F1: 0.9553, Train Class 1 F1: 0.8678
# Val Loss: 0.5731, Val F1: 0.8511, Val Class 1 F1: 0.5845
# EarlyStopping counter: 1 out of 10
# Epoch 46/100
# Train Loss: 0.1852, Train F1: 0.9552, Train Class 1 F1: 0.8681
# Val Loss: 0.5726, Val F1: 0.8702, Val Class 1 F1: 0.6167
# EarlyStopping counter: 2 out of 10
# Epoch 47/100
# Train Loss: 0.1820, Train F1: 0.9541, Train Class 1 F1: 0.8650
# Val Loss: 0.5751, Val F1: 0.8691, Val Class 1 F1: 0.6141
# EarlyStopping counter: 3 out of 10
# Epoch 48/100
# Train Loss: 0.1757, Train F1: 0.9583, Train Class 1 F1: 0.8766
# Val Loss: 0.5791, Val F1: 0.8715, Val Class 1 F1: 0.6188
# EarlyStopping counter: 4 out of 10
# Epoch 49/100
# Train Loss: 0.1698, Train F1: 0.9573, Train Class 1 F1: 0.8744
# Val Loss: 0.5860, Val F1: 0.8768, Val Class 1 F1: 0.6280
# Validation score improved! Overall F1: 0.8768, Class 1 F1: 0.6280
# Epoch 50/100
# Train Loss: 0.1647, Train F1: 0.9591, Train Class 1 F1: 0.8791
# Val Loss: 0.5977, Val F1: 0.8540, Val Class 1 F1: 0.5889
# EarlyStopping counter: 1 out of 10
# Epoch 51/100
# Train Loss: 0.1591, Train F1: 0.9606, Train Class 1 F1: 0.8836
# Val Loss: 0.6030, Val F1: 0.8816, Val Class 1 F1: 0.6334
# Validation score improved! Overall F1: 0.8816, Class 1 F1: 0.6334
# Epoch 52/100
# Train Loss: 0.1531, Train F1: 0.9609, Train Class 1 F1: 0.8847
# Val Loss: 0.5949, Val F1: 0.8719, Val Class 1 F1: 0.6185
# EarlyStopping counter: 1 out of 10
# Epoch 53/100
# Train Loss: 0.1521, Train F1: 0.9614, Train Class 1 F1: 0.8858
# Val Loss: 0.5924, Val F1: 0.8728, Val Class 1 F1: 0.6188
# EarlyStopping counter: 2 out of 10
# Epoch 54/100
# Train Loss: 0.1462, Train F1: 0.9609, Train Class 1 F1: 0.8851
# Val Loss: 0.6028, Val F1: 0.8715, Val Class 1 F1: 0.6168
# EarlyStopping counter: 3 out of 10
# Epoch 55/100
# Train Loss: 0.1411, Train F1: 0.9626, Train Class 1 F1: 0.8898
# Val Loss: 0.6101, Val F1: 0.8689, Val Class 1 F1: 0.6126
# EarlyStopping counter: 4 out of 10
# Epoch 56/100
# Train Loss: 0.1383, Train F1: 0.9644, Train Class 1 F1: 0.8947
# Val Loss: 0.6142, Val F1: 0.8667, Val Class 1 F1: 0.6076
# EarlyStopping counter: 5 out of 10
# Epoch 57/100
# Train Loss: 0.1339, Train F1: 0.9641, Train Class 1 F1: 0.8942
# Val Loss: 0.6211, Val F1: 0.8787, Val Class 1 F1: 0.6303
# EarlyStopping counter: 6 out of 10
# Epoch 58/100
# Train Loss: 0.1304, Train F1: 0.9652, Train Class 1 F1: 0.8974
# Val Loss: 0.6262, Val F1: 0.8732, Val Class 1 F1: 0.6203
# EarlyStopping counter: 7 out of 10
# Epoch 59/100
# Train Loss: 0.1291, Train F1: 0.9664, Train Class 1 F1: 0.9005
# Val Loss: 0.6305, Val F1: 0.8706, Val Class 1 F1: 0.6154
# EarlyStopping counter: 8 out of 10
# Epoch 60/100
# Train Loss: 0.1261, Train F1: 0.9669, Train Class 1 F1: 0.9021
# Val Loss: 0.6390, Val F1: 0.8768, Val Class 1 F1: 0.6250
# EarlyStopping counter: 9 out of 10
# Epoch 61/100
# Train Loss: 0.1226, Train F1: 0.9672, Train Class 1 F1: 0.9029
# Val Loss: 0.6436, Val F1: 0.8797, Val Class 1 F1: 0.6297
# EarlyStopping counter: 10 out of 10
# Early stopping triggered
# Evaluation Results:
# Accuracy: 0.8821
# F1 Score (Weighted): 0.8816
# F1 Score for Class 1: 0.6334
# Confusion Matrix:
# [[5544, 407], [431, 724]]
#
# WORD2VEC Test Results:
# Overall F1 score: 0.8816
# Class 1 F1 score: 0.6334
# Accuracy: 0.8821
# Model saved as 'best_word2vec_bilstm.pt'
# Model info saved as 'word2vec_bilstm_info.pkl'
